# %% [markdown]
# <a href="https://colab.research.google.com/github/raynardj/python4ml/blob/master/experiments/Sentiment_Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Experimente on Sentiment Analysis

# %%
# !!pip install --force-reinstall git+https://github.com/raynardj/forge

# %%
from forgebox.ftorch import layers
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     293         """
# --> 294         return _ConnectionFairy._checkout(self)
#     295
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     236     def _do_get(self):
# --> 237         return self._create_connection()
#     238
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-c84fafa64704> in <module>()
# ----> 1 from forgebox.ftorch import layers
#
# /usr/local/lib/python3.6/dist-packages/forgebox/ftorch/__init__.py in <module>()
# ----> 1 from ..apicore import forgedb
#       2 from .callbacks import recorddf
#       3 import torch
#       4 import os
#       5 from datetime import datetime
#
# /usr/local/lib/python3.6/dist-packages/forgebox/apicore.py in <module>()
# ----> 1 from .dbcore import session, taskModel, weightModel, hyperParam, \
#       2     hyperParamLog, dataFormat, metricModel, metricLog, trainModel, logModel
#       3 from pathlib import Path
#       4 from datetime import datetime
#       5 import json, os
#
# /usr/local/lib/python3.6/dist-packages/forgebox/dbcore/__init__.py in <module>()
#       8 engine = create_engine(SQLALCHEMY_DATABASE_URI)
#       9
# ---> 10 Base.prepare(engine, reflect=True)
#      11
#      12 session = Session(engine)
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/ext/automap.py in prepare(cls, engine, reflect, schema, classname_for_table, collection_class, name_for_scalar_relationship, name_for_collection_relationship, generate_relationship)
#     760                 schema=schema,
#     761                 extend_existing=True,
# --> 762                 autoload_replace=False,
#     763             )
#     764
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/sql/schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, resolve_fks, **dialect_kwargs)
#    4177             bind = _bind_or_error(self)
#    4178
# -> 4179         with bind.connect() as conn:
#    4180
#    4181             reflect_opts = {
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2191         """
#    2192
# -> 2193         return self._connection_cls(self, **kwargs)
#    2194
#    2195     @util.deprecated(
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2291         """
#    2292         return self._wrap_pool_connect(
# -> 2293             self.pool.unique_connection, _connection
#    2294         )
#    2295
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2264             if connection is None:
#    2265                 Connection._handle_dbapi_exception_noconnection(
# -> 2266                     e, dialect, self
#    2267                 )
#    2268             else:
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2260         dialect = self.dialect
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#    2264             if connection is None:
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     292
#     293         """
# --> 294         return _ConnectionFairy._checkout(self)
#     295
#     296     def _create_connection(self):
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     749     def _checkout(cls, pool, threadconns=None, fairy=None):
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#     753             fairy._pool = pool
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     481     @classmethod
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#     485             dbapi_connection = rec.get_connection()
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     235
#     236     def _do_get(self):
# --> 237         return self._create_connection()
#     238
#     239     def recreate(self):
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     297         """Called by subclasses to create a new ConnectionRecord."""
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#     301     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     426         self.__pool = pool
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#     430
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     628         try:
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#     632             self.connection = connection
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# /usr/local/lib/python3.6/dist-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     451
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#     455     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file
# (Background on this error at: http://sqlalche.me/e/e3q8)
