# %% [markdown]
# # Collaborative Filtering model on MovieLens

# %% [markdown]
# Download the 20m [movielens dataset](http://files.grouplens.org/datasets/movielens/ml-20m.zip)

# %% [markdown]
# You can use the aria2c or wget to download

# %%
# %cd /data
# !!aria2c -x5 http://files.grouplens.org/datasets/movielens/ml-20m.zip
# !!unzip ml-20m.zip

# %%
import pandas as pd
import numpy as np
import os
import torch
from p3self.matchbox import Trainer

# %%
DATA = "/data/ml-latest-small/"
BS = 4000
DIM = 50
CUDA = torch.cuda.is_available()
print(CUDA)
# Out:
# True

# %%
files = os.listdir(DATA)
files
# Out:
# ['movies.csv', 'links.csv', 'tags.csv', 'ratings.csv', 'README.txt']

# %%
data = dict()
for f in files:
    if f[-3:]=="csv":
        data[f.split(".")[0]] = pd.read_csv(DATA+f)

# %% [markdown]
# ### Check Data

# %%
from IPython.display import display
list(display(k,v.sample(5)) for k,v in data.items())
# Out:
# 'movies'
#       movieId                                              title  \
# 337       373                               Red Rock West (1992)
# 7349    71535                                  Zombieland (2009)
# 546       620  Scream of Stone (Cerro Torre: Schrei aus Stein...
# 7876    89203                                  Magic Trip (2011)
# 3796     4867                    Riding in Cars with Boys (2001)
#
#                     genres
# 337               Thriller
# 7349  Action|Comedy|Horror
# 546                  Drama
# 7876           Documentary
# 3796          Comedy|Drama
# 'links'
#       movieId   imdbId   tmdbId
# 6195    34517    61398  42689.0
# 6710    53138   455596  14208.0
# 4088     5354    64117  28289.0
# 7211    68194  1226271  21641.0
# 1129     1391   116996     75.0
# 'tags'
#       userId  movieId                   tag   timestamp
# 530      364   118997               musical  1444530098
# 37        94    64957         original plot  1291781246
# 367      364     1176  Krzysztof Kieslowski  1444528941
# 1173     547   103372             toplist13  1383625950
# 160      212    60684              dystopia  1253926517
# 'ratings'
#        userId  movieId  rating   timestamp
# 43312     310      628     3.0  1414188046
# 53037     384    27851     3.5  1154367666
# 15114      99      588     3.0   938586006
# 29225     212    60040     3.0  1227938927
# 16704     105     7149     3.5  1100606316
# [None, None, None, None]

# %% [markdown]
# ## Model on rating

# %%
data["ratings"].sample(5)
# Out:
#        userId  movieId  rating   timestamp
# 91262     605     3717     1.0   980174247
# 62952     456     6365     4.5  1432308271
# 78232     544    79132     4.0  1435786926
# 76078     529      953     3.0   959965606
# 92837     615    81562     3.5  1454913597

# %%
len(data["ratings"])
# Out:
# 100004

# %%
userId = list(set(data["ratings"]["userId"]))
movieId = list(set(data["ratings"]["movieId"]))
print(len(userId),len(movieId))
# Out:
# 671 9066

# %% [markdown]
# ### Mapping
# user to index, movie to index, index to user, index to movie

# %%
u2i = dict((v,k) for k,v in enumerate(userId))
m2i = dict((v,k) for k,v in enumerate(movieId))
i2u = dict((k,v) for k,v in enumerate(userId))
i2m = dict((k,v) for k,v in enumerate(movieId))

# %%
from torch.utils.data import DataLoader,Dataset

# %% [markdown]
# ### Separate train/valid dataset

# %%
train_pick = np.random.rand(len(data["ratings"]))>.2
valid_pick = ~train_pick

# %%
train_pick,valid_pick
# Out:
# (array([ True, False, False, ..., False, False,  True]),
#  array([False,  True,  True, ...,  True,  True, False]))

# %%
train_df = data["ratings"][train_pick].reset_index()
valid_df = data["ratings"][valid_pick].reset_index()

# %% [markdown]
# ### Data generator

# %%
class reco_data(Dataset):
    def __init__(self,df):
        self.df=df
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self,idx):
        row = self.df.loc[idx]
        return u2i[int(row["userId"])],m2i[int(row["movieId"])],row["rating"]/5

# %%
train = reco_data(train_df)
valid = reco_data(valid_df)

# %% [markdown]
# ## Basic Cross Filtering

# %%
from torch import nn

# %%
class embeddings(nn.Module):
    def __init__(self):
        super(embeddings,self).__init__()
        self.emb_u = nn.Embedding(len(userId), DIM)
        self.emb_m = nn.Embedding(len(movieId), DIM)
        
    def forward(self,u,m):
        return self.emb_u(u),self.emb_m(m)

# %%
class cf(nn.Module):
    def __init__(self):
        super(cf,self).__init__()
        self.ebd = embeddings()
    
    def forward(self,u,m):
        u_vec,m_vec = self.ebd(u,m)
        return u_vec * m_vec
    
class cfnn(nn.Module):
    def __init__(self):
        super(cfnn,self).__init__()
        self.cf = cf()
        self.fcb = nn.Sequential(*[nn.Linear(DIM,512,bias=False),
                                   nn.BatchNorm1d(512),
                                   nn.LeakyReLU(inplace=True),
                                   nn.Linear(512,1,bias=False),
                                   nn.BatchNorm1d(1),
                                   nn.Sigmoid()
                                  ],
                                )
    
    def forward(self,u,m):
        x = self.cf(u,m)
        return self.fcb(x)

# %%
cfmodel = cfnn()

# %%
from torch.optim import Adam
mse = nn.MSELoss()
opt = Adam(cfmodel.parameters(),amsgrad=True)
if CUDA:
    cfmodel.cuda()

# %% [markdown]
# Step function for train and valid

# %%
def action(*args,**kwargs):
    u,m,y = args[0]
    opt.zero_grad()
    if CUDA:
        u,m,y  = u.cuda(),m.cuda(),y.cuda()
        
    y_ = cfmodel(u,m) # prediction
    
    loss = mse(y_,y.unsqueeze(-1).float())
    
    loss.backward()
    opt.step()
    
    return {"mse":loss.item()}

def val_action(*args,**kwargs):
    u,m,y = args[0]
    if CUDA:
        u,m,y = u.cuda(),m.cuda(),y.cuda()
    y_ = cfmodel(u,m)
    loss = mse(y_,y.unsqueeze(-1).float())
    
    return {"mse":loss.item()}

# %%
trainer = Trainer(train, val_dataset=valid, batch_size=BS, print_on = 5)

trainer.action = action
trainer.val_action = val_action

# %%
trainer.train(10)
# Out:
# ⭐[ep_0_i_19]	mse	0.094: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_0_i_5]	mse	0.092: 100%|██████████| 6/6 [00:03<00:00,  1.79it/s]
# ⭐[ep_1_i_19]	mse	0.088: 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]
# 😎[val_ep_1_i_5]	mse	0.087: 100%|██████████| 6/6 [00:03<00:00,  1.77it/s]
# ⭐[ep_2_i_19]	mse	0.084: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_2_i_5]	mse	0.084: 100%|██████████| 6/6 [00:03<00:00,  1.79it/s]
# ⭐[ep_3_i_19]	mse	0.082: 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]
# 😎[val_ep_3_i_5]	mse	0.082: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_4_i_19]	mse	0.079: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_4_i_5]	mse	0.079: 100%|██████████| 6/6 [00:03<00:00,  1.77it/s]
# ⭐[ep_5_i_19]	mse	0.075: 100%|██████████| 20/20 [00:13<00:00,  1.46it/s]
# 😎[val_ep_5_i_5]	mse	0.077: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_6_i_19]	mse	0.073: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_6_i_5]	mse	0.075: 100%|██████████| 6/6 [00:03<00:00,  1.76it/s]
# ⭐[ep_7_i_19]	mse	0.071: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_7_i_5]	mse	0.073: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_8_i_19]	mse	0.069: 100%|██████████| 20/20 [00:13<00:00,  1.46it/s]
# 😎[val_ep_8_i_5]	mse	0.072: 100%|██████████| 6/6 [00:03<00:00,  1.77it/s]
# ⭐[ep_9_i_19]	mse	0.066: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_9_i_5]	mse	0.070: 100%|██████████| 6/6 [00:03<00:00,  1.73it/s]

# %% [markdown]
# ### Wider NN

# %% [markdown]
# Change the hidden layer to 1024

# %%
class cfnn2(nn.Module):
    def __init__(self):
        super(cfnn2,self).__init__()
        self.cf = cf()
        self.fcb = nn.Sequential(*[nn.Linear(DIM,1024,bias=False),
                                   nn.BatchNorm1d(1024),
                                   nn.LeakyReLU(inplace=True),
                                   nn.Linear(1024,1,bias=False),
                                   nn.BatchNorm1d(1),
                                   nn.Sigmoid()
                                  ],
                                )
    
    def forward(self,u,m):
        x = self.cf(u,m)
        return self.fcb(x)

# %%
cfmodel = cfnn2()

from torch.optim import Adam
mse = nn.MSELoss()
opt = Adam(cfmodel.parameters(),amsgrad=True)
if CUDA:
    cfmodel.cuda()

trainer = Trainer(train, val_dataset=valid, batch_size=BS, print_on = 5)

trainer.action = action
trainer.val_action = val_action

trainer.train(10)
# Out:
# ⭐[ep_0_i_19]	mse	0.107: 100%|██████████| 21/21 [00:13<00:00,  1.54it/s]
# 😎[val_ep_0_i_4]	mse	0.108: 100%|██████████| 5/5 [00:03<00:00,  1.49it/s]
# ⭐[ep_1_i_19]	mse	0.100: 100%|██████████| 21/21 [00:13<00:00,  1.53it/s]
# 😎[val_ep_1_i_4]	mse	0.101: 100%|██████████| 5/5 [00:03<00:00,  1.44it/s]
# ⭐[ep_2_i_19]	mse	0.092: 100%|██████████| 21/21 [00:13<00:00,  1.53it/s]
# 😎[val_ep_2_i_4]	mse	0.095: 100%|██████████| 5/5 [00:03<00:00,  1.50it/s]
# ⭐[ep_3_i_19]	mse	0.087: 100%|██████████| 21/21 [00:13<00:00,  1.54it/s]
# 😎[val_ep_3_i_4]	mse	0.090: 100%|██████████| 5/5 [00:03<00:00,  1.47it/s]
# ⭐[ep_4_i_19]	mse	0.082: 100%|██████████| 21/21 [00:13<00:00,  1.52it/s]
# 😎[val_ep_4_i_4]	mse	0.087: 100%|██████████| 5/5 [00:03<00:00,  1.48it/s]
# ⭐[ep_5_i_19]	mse	0.079: 100%|██████████| 21/21 [00:13<00:00,  1.54it/s]
# 😎[val_ep_5_i_4]	mse	0.084: 100%|██████████| 5/5 [00:03<00:00,  1.49it/s]
# ⭐[ep_6_i_19]	mse	0.076: 100%|██████████| 21/21 [00:13<00:00,  1.55it/s]
# 😎[val_ep_6_i_4]	mse	0.081: 100%|██████████| 5/5 [00:03<00:00,  1.49it/s]
# ⭐[ep_7_i_19]	mse	0.075: 100%|██████████| 21/21 [00:13<00:00,  1.54it/s]
# 😎[val_ep_7_i_4]	mse	0.079: 100%|██████████| 5/5 [00:03<00:00,  1.50it/s]
# ⭐[ep_8_i_19]	mse	0.073: 100%|██████████| 21/21 [00:13<00:00,  1.53it/s]
# 😎[val_ep_8_i_4]	mse	0.077: 100%|██████████| 5/5 [00:03<00:00,  1.49it/s]
# ⭐[ep_9_i_19]	mse	0.070: 100%|██████████| 21/21 [00:13<00:00,  1.54it/s]
# 😎[val_ep_9_i_4]	mse	0.075: 100%|██████████| 5/5 [00:03<00:00,  1.48it/s]

# %% [markdown]
# ### Add dropout

# %%
class cfnn3(nn.Module):
    def __init__(self):
        super(cfnn3,self).__init__()
        self.cf = cf()
        self.fcb = nn.Sequential(*[nn.Linear(DIM,512,bias=False),
                                   nn.BatchNorm1d(512),
                                   nn.LeakyReLU(inplace=True),
                                   nn.Dropout(.3),
                                   nn.Linear(512,1,bias=False),
                                   nn.BatchNorm1d(1),
                                   nn.Sigmoid()
                                  ],
                                )
    
    def forward(self,u,m):
        x = self.cf(u,m)
        return self.fcb(x)

# %%
cfmodel = cfnn3()

from torch.optim import Adam
mse = nn.MSELoss()
opt = Adam(cfmodel.parameters(),amsgrad=True)
if CUDA:
    cfmodel.cuda()

trainer = Trainer(train, val_dataset=valid, batch_size=BS, print_on = 5)

trainer.action = action
trainer.val_action = val_action

trainer.train(10)
# Out:
# ⭐[ep_0_i_19]	mse	0.097: 100%|██████████| 21/21 [00:13<00:00,  1.55it/s]
# 😎[val_ep_0_i_4]	mse	0.098: 100%|██████████| 5/5 [00:03<00:00,  1.48it/s]
# ⭐[ep_1_i_19]	mse	0.093: 100%|██████████| 21/21 [00:13<00:00,  1.57it/s]
# 😎[val_ep_1_i_4]	mse	0.094: 100%|██████████| 5/5 [00:03<00:00,  1.52it/s]
# ⭐[ep_2_i_19]	mse	0.089: 100%|██████████| 21/21 [00:13<00:00,  1.59it/s]
# 😎[val_ep_2_i_4]	mse	0.091: 100%|██████████| 5/5 [00:03<00:00,  1.54it/s]
# ⭐[ep_3_i_19]	mse	0.086: 100%|██████████| 21/21 [00:13<00:00,  1.58it/s]
# 😎[val_ep_3_i_4]	mse	0.087: 100%|██████████| 5/5 [00:03<00:00,  1.47it/s]
# ⭐[ep_4_i_19]	mse	0.082: 100%|██████████| 21/21 [00:13<00:00,  1.56it/s]
# 😎[val_ep_4_i_4]	mse	0.084: 100%|██████████| 5/5 [00:03<00:00,  1.52it/s]
# ⭐[ep_5_i_19]	mse	0.079: 100%|██████████| 21/21 [00:13<00:00,  1.57it/s]
# 😎[val_ep_5_i_4]	mse	0.081: 100%|██████████| 5/5 [00:03<00:00,  1.52it/s]
# ⭐[ep_6_i_19]	mse	0.076: 100%|██████████| 21/21 [00:13<00:00,  1.56it/s]
# 😎[val_ep_6_i_4]	mse	0.078: 100%|██████████| 5/5 [00:03<00:00,  1.48it/s]
# ⭐[ep_7_i_19]	mse	0.073: 100%|██████████| 21/21 [00:13<00:00,  1.58it/s]
# 😎[val_ep_7_i_4]	mse	0.076: 100%|██████████| 5/5 [00:03<00:00,  1.47it/s]
# ⭐[ep_8_i_19]	mse	0.071: 100%|██████████| 21/21 [00:13<00:00,  1.56it/s]
# 😎[val_ep_8_i_4]	mse	0.074: 100%|██████████| 5/5 [00:03<00:00,  1.52it/s]
# ⭐[ep_9_i_19]	mse	0.068: 100%|██████████| 21/21 [00:13<00:00,  1.56it/s]
# 😎[val_ep_9_i_4]	mse	0.072: 100%|██████████| 5/5 [00:03<00:00,  1.54it/s]

# %% [markdown]
# ### No Sigmoid as final activation

# %%
class cfnn4(nn.Module):
    def __init__(self):
        super(cfnn4,self).__init__()
        self.cf = cf()
        self.fcb = nn.Sequential(*[nn.Linear(DIM,512,bias=False),
                                   nn.BatchNorm1d(512),
                                   nn.LeakyReLU(inplace=True),
                                   nn.Dropout(.3),
                                   nn.Linear(512,1,bias=False),
                                   nn.BatchNorm1d(1),
                                  ],
                                )
    
    def forward(self,u,m):
        x = self.cf(u,m)
        return self.fcb(x)

# %%
cfmodel = cfnn4()

from torch.optim import Adam
mse = nn.MSELoss()
opt = Adam(cfmodel.parameters(),amsgrad=True)
if CUDA:
    cfmodel.cuda()

trainer = Trainer(train, val_dataset=valid, batch_size=BS, print_on = 5)

trainer.action = action
trainer.val_action = val_action

trainer.train(10)
# Out:
# ⭐[ep_0_i_19]	mse	0.603: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_0_i_5]	mse	0.593: 100%|██████████| 6/6 [00:03<00:00,  1.76it/s]
# ⭐[ep_1_i_19]	mse	0.558: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_1_i_5]	mse	0.554: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_2_i_19]	mse	0.519: 100%|██████████| 20/20 [00:13<00:00,  1.45it/s]
# 😎[val_ep_2_i_5]	mse	0.517: 100%|██████████| 6/6 [00:03<00:00,  1.77it/s]
# ⭐[ep_3_i_19]	mse	0.482: 100%|██████████| 20/20 [00:13<00:00,  1.45it/s]
# 😎[val_ep_3_i_5]	mse	0.483: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_4_i_19]	mse	0.450: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_4_i_5]	mse	0.452: 100%|██████████| 6/6 [00:03<00:00,  1.77it/s]
# ⭐[ep_5_i_19]	mse	0.424: 100%|██████████| 20/20 [00:13<00:00,  1.46it/s]
# 😎[val_ep_5_i_5]	mse	0.422: 100%|██████████| 6/6 [00:03<00:00,  1.72it/s]
# ⭐[ep_6_i_19]	mse	0.394: 100%|██████████| 20/20 [00:13<00:00,  1.46it/s]
# 😎[val_ep_6_i_5]	mse	0.395: 100%|██████████| 6/6 [00:03<00:00,  1.76it/s]
# ⭐[ep_7_i_19]	mse	0.371: 100%|██████████| 20/20 [00:13<00:00,  1.45it/s]
# 😎[val_ep_7_i_5]	mse	0.371: 100%|██████████| 6/6 [00:03<00:00,  1.77it/s]
# ⭐[ep_8_i_19]	mse	0.345: 100%|██████████| 20/20 [00:13<00:00,  1.44it/s]
# 😎[val_ep_8_i_5]	mse	0.348: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_9_i_19]	mse	0.325: 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]
# 😎[val_ep_9_i_5]	mse	0.325: 100%|██████████| 6/6 [00:03<00:00,  1.77it/s]

# %% [markdown]
# ### No neural network at all, linear output

# %%
class cf_model(nn.Module):
    def __init__(self):
        super(cf_model,self).__init__()
        self.cf = cf()
        self.fcb = nn.Sequential(*[nn.Linear(DIM,1,bias=False),
                                   nn.Sigmoid(),])
        
    def forward(self,u,m):
        x = self.cf(u,m)
        return self.fcb(x)
    
cfmodel = cf_model()

from torch.optim import Adam
mse = nn.MSELoss()
opt = Adam(cfmodel.parameters(),amsgrad=True)
if CUDA:
    cfmodel.cuda()

trainer = Trainer(train, val_dataset=valid, batch_size=BS, print_on = 5)

trainer.action = action
trainer.val_action = val_action

trainer.train(10)
# Out:
# ⭐[ep_0_i_19]	mse	0.101: 100%|██████████| 20/20 [00:13<00:00,  1.50it/s]
# 😎[val_ep_0_i_5]	mse	0.100: 100%|██████████| 6/6 [00:03<00:00,  1.81it/s]
# ⭐[ep_1_i_19]	mse	0.095: 100%|██████████| 20/20 [00:13<00:00,  1.50it/s]
# 😎[val_ep_1_i_5]	mse	0.096: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_2_i_19]	mse	0.092: 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]
# 😎[val_ep_2_i_5]	mse	0.093: 100%|██████████| 6/6 [00:03<00:00,  1.71it/s]
# ⭐[ep_3_i_19]	mse	0.090: 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]
# 😎[val_ep_3_i_5]	mse	0.091: 100%|██████████| 6/6 [00:03<00:00,  1.80it/s]
# ⭐[ep_4_i_19]	mse	0.089: 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]
# 😎[val_ep_4_i_5]	mse	0.090: 100%|██████████| 6/6 [00:03<00:00,  1.74it/s]
# ⭐[ep_5_i_19]	mse	0.089: 100%|██████████| 20/20 [00:13<00:00,  1.49it/s]
# 😎[val_ep_5_i_5]	mse	0.089: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_6_i_19]	mse	0.088: 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]
# 😎[val_ep_6_i_5]	mse	0.089: 100%|██████████| 6/6 [00:03<00:00,  1.79it/s]
# ⭐[ep_7_i_19]	mse	0.088: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s]
# 😎[val_ep_7_i_5]	mse	0.089: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]
# ⭐[ep_8_i_19]	mse	0.089: 100%|██████████| 20/20 [00:13<00:00,  1.49it/s]
# 😎[val_ep_8_i_5]	mse	0.089: 100%|██████████| 6/6 [00:03<00:00,  1.79it/s]
# ⭐[ep_9_i_19]	mse	0.088: 100%|██████████| 20/20 [00:13<00:00,  1.46it/s]
# 😎[val_ep_9_i_5]	mse	0.089: 100%|██████████| 6/6 [00:03<00:00,  1.78it/s]

# %% [markdown]
# So far the 1st model is best on valid inference score

# %% [markdown]
# ### Visualize

# %%
movie_arr = cfmodel.cf.ebd.emb_m.weight.data.cpu().numpy()

# %%
np.save("/data/ml-latest-small/movie_arr.npy",movie_arr)

# %%
len(i2m),movie_arr.shape
# Out:
# (9066, (9066, 50))

# %%
data["movies"].sample(5)
# Out:
#       movieId                     title                genres
# 5683    25850            Holiday (1938)  Comedy|Drama|Romance
# 4818     6800              Cobra (1986)          Action|Crime
# 3105     3886  Steal This Movie! (2000)                 Drama
# 6137    33380           25 Watts (2001)          Comedy|Drama
# 1148     1414             Mother (1996)                Comedy

# %%
ratings = data["ratings"]

# %%
ratings_avg = pd.pivot_table(ratings,values="rating",index=["movieId"],aggfunc="mean")

# %%
ratings_avg["arr_id"] = ratings_avg.reset_index()["movieId"].apply(lambda x:m2i[x])

# %%
mvrt = pd.merge(ratings_avg.reset_index(),data["movies"],on="movieId")

# %%
mvrt.sort_values(by="rating",ascending=False)
# Out:
#       movieId  rating  arr_id  \
# 9065   163949     5.0     NaN
# 7297    71180     5.0     NaN
# 6629    51471     5.0     NaN
# 6662    52617     5.0     NaN
# 6704    53887     5.0     NaN
# 6717    54251     5.0     NaN
# 6726    54328     5.0     NaN
# 6785    55555     5.0     NaN
# 6836    56869     5.0     NaN
# 6843    57038     5.0     NaN
# 6894    58649     5.0     NaN
# 6918    59273     5.0     NaN
# 6925    59392     5.0     NaN
# 6929    59447     5.0     NaN
# 6932    59549     5.0     NaN
# 6937    59684     5.0     NaN
# 6971    60384     5.0     NaN
# 6979    60674     5.0     NaN
# 6992    61013     5.0     NaN
# 7006    61250     5.0     NaN
# 7024    62115     5.0     NaN
# 7066    63836     5.0     NaN
# 7080    64278     5.0     NaN
# 7092    64660     5.0     NaN
# 7104    65037     5.0     NaN
# 7112    65216     5.0     NaN
# 7170    67504     5.0     NaN
# 779       961     5.0  1068.0
# 7246    69761     5.0     NaN
# 7281    70762     5.0     NaN
# ...       ...     ...     ...
# 5519     8777     0.5  8617.0
# 4697     6566     0.5  7279.0
# 7520    78122     0.5     NaN
# 6844    57223     0.5     NaN
# 5535     8811     0.5  8973.0
# 8070    95740     0.5     NaN
# 6991    60990     0.5     NaN
# 9016   152057     0.5     NaN
# 4257     5672     0.5  8063.0
# 6247    39408     0.5     NaN
# 6738    54768     0.5     NaN
# 7133    66066     0.5     NaN
# 7255    69974     0.5     NaN
# 8791   129250     0.5     NaN
# 7009    61348     0.5     NaN
# 6963    60137     0.5     NaN
# 6524    48591     0.5     NaN
# 7837    88950     0.5     NaN
# 7256    70121     0.5     NaN
# 1742     2191     0.5  2414.0
# 5737    26188     0.5     NaN
# 5728    26157     0.5     NaN
# 6745    54910     0.5     NaN
# 5371     8290     0.5  3588.0
# 5704    26009     0.5     NaN
# 4085     5356     0.5  6116.0
# 6445    46574     0.5     NaN
# 3725     4753     0.5  5364.0
# 5679    25901     0.5     NaN
# 2276     2845     0.5  3117.0
#
#                                                   title  \
# 9065  The Beatles: Eight Days a Week - The Touring Y...
# 7297                               Padre padrone (1977)
# 6629                               Amazing Grace (2006)
# 6662       Woman on the Beach (Haebyeonui yeoin) (2006)
# 6704                                O Lucky Man! (1973)
# 6717                                Dorian Blues (2004)
# 6726           My Best Friend (Mon meilleur ami) (2006)
# 6785  Edge of Heaven, The (Auf der anderen Seite) (2...
# 6836                  Drained (O cheiro do Ralo) (2006)
# 6843  To the Left of the Father (Lavoura Arcaica) (2...
# 6894                                    Napoléon (1927)
# 6918                                   Delirious (2006)
# 6925                  Stargate: The Ark of Truth (2008)
# 6929                                     Fiorile (1993)
# 6932                                     Shelter (2007)
# 6937                                Lake of Fire (2006)
# 6971          Z Channel: A Magnificent Obsession (2004)
# 6979                         Stargate: Continuum (2008)
# 6992                           Absolute Giganten (1999)
# 7006                            House Bunny, The (2008)
# 7024                                 Six Shooter (2004)
# 7066                          Manson Family, The (2003)
# 7080              Pervert's Guide to Cinema, The (2006)
# 7092                               Waiter (Ober) (2006)
# 7104                                       Ben X (2007)
# 7112                                    Defiance (2008)
# 7170  Land of Silence and Darkness (Land des Schweig...
# 779                       Little Lord Fauntleroy (1936)
# 7246  Through the Olive Trees (Zire darakhatan zeyto...
# 7281                    Curiosity of Chance, The (2006)
# ...                                                 ...
# 5519     Roadkill (a.k.a. Roadkill: Move or Die) (1989)
# 4697                     Spy Kids 3-D: Game Over (2003)
# 7520                            Peter & the Wolf (2006)
# 6844                         D-War (Dragon Wars) (2007)
# 5535                                   Yu-Gi-Oh! (2004)
# 8070  Adventures of Mary-Kate and Ashley, The: The C...
# 6991  End of Summer, The (Early Autumn) (Kohayagawa-...
# 9016                                 Miles Ahead (2016)
# 4257  Pokemon 4 Ever (a.k.a. Pokémon 4: The Movie) (...
# 6247                   Left Behind: World at War (2005)
# 6738                              Daddy Day Camp (2007)
# 7133                               Grudge 3, The (2009)
# 7255                         Shiver (Eskalofrío) (2008)
# 8791                                  Superfast! (2015)
# 7009                              Disaster Movie (2008)
# 6963                         Rape of Europa, The (2006)
# 6524                               Grudge 2, The (2006)
# 7837                            Conspirator, The (2010)
# 7256                    'Neath the Arizona Skies (1934)
# 1742                                Merry War, A (1997)
# 5737               Heart Is a Lonely Hunter, The (1968)
# 5728                    Manos: The Hands of Fate (1966)
# 6745  Behind the Mask: The Rise of Leslie Vernon (2006)
# 5371                                    Mitchell (1975)
# 5704      Burmese Harp, The (Biruma no tategoto) (1956)
# 4085                  Giant Spider Invasion, The (1975)
# 6445                             OH in Ohio, The (2006)
# 3725                                        Vamp (1986)
# 5679  Henry V (Chronicle History of King Henry the F...
# 2276                                   Whiteboyz (1999)
#
#                                     genres
# 9065                           Documentary
# 7297                                 Drama
# 6629                         Drama|Romance
# 6662                          Comedy|Drama
# 6704          Comedy|Drama|Fantasy|Musical
# 6717                                Comedy
# 6726                                Comedy
# 6785                                 Drama
# 6836                                Comedy
# 6843                                 Drama
# 6894                             Drama|War
# 6918                          Comedy|Drama
# 6925                 Action|Fantasy|Sci-Fi
# 6929                                 Drama
# 6932                         Drama|Romance
# 6937                           Documentary
# 6971                           Documentary
# 6979                                Sci-Fi
# 6992           Action|Comedy|Drama|Romance
# 7006                                Comedy
# 7024                          Comedy|Drama
# 7066                    Crime|Drama|Horror
# 7080                           Documentary
# 7092                                Comedy
# 7104                                 Drama
# 7112                    Drama|Thriller|War
# 7170                           Documentary
# 779                                  Drama
# 7246                                 Drama
# 7281                                Comedy
# ...                                    ...
# 5519                                 Drama
# 4697             Action|Adventure|Children
# 7520                     Animation|Musical
# 6844        Action|Adventure|Drama|Fantasy
# 5535    Action|Adventure|Animation|Fantasy
# 8070              Children|Musical|Mystery
# 6991                                 Drama
# 9016                                 Drama
# 4257  Adventure|Animation|Children|Fantasy
# 6247                                 Drama
# 6738                       Children|Comedy
# 7133                                Horror
# 7255                       Horror|Thriller
# 8791                    (no genres listed)
# 7009                                Comedy
# 6963                           Documentary
# 6524         Drama|Horror|Mystery|Thriller
# 7837                                 Drama
# 7256                               Western
# 1742                                Comedy
# 5737                                 Drama
# 5728                                Horror
# 6745                Comedy|Horror|Thriller
# 5371                          Action|Crime
# 5704                             Drama|War
# 4085                         Horror|Sci-Fi
# 6445                                Comedy
# 3725                         Comedy|Horror
# 5679                             Drama|War
# 2276                          Comedy|Drama
#
# [9066 rows x 5 columns]
