# %% [markdown]
# # Guess Industry Name With The Stock Indices

# %%
import pandas as pd

# %%
data_df = pd.read_csv("/data/stock_hist_data.csv")
data_df.sample(10)
# Out:
#            sn    ts_code  trade_date   open   high    low  close  pre_close  \
# 6164962   851  600128.SH    20150504  17.28  17.77  17.02  17.57      17.24
# 2580455  1042  002672.SZ    20140327  37.49  37.49  36.51  36.70      37.08
# 3274091   136  600308.SH    20180404   5.80   5.86   5.74   5.75       5.80
# 3429061  3020  002011.SZ    20050614   6.70   6.78   6.41   6.43       6.70
# 6733531   985  600558.SH    20140521   7.35   7.40   7.22   7.39       7.37
# 6469851  1023  001696.SZ    20140227   5.10   5.27   5.05   5.11       5.10
# 4645807   662  600439.SH    20160121   5.55   5.68   5.36   5.37       5.64
# 2168133  1914  002166.SZ    20100705  23.40  24.99  23.25  24.06      23.77
# 4610506   727  601933.SH    20151027  11.12  11.34  10.95  11.29      11.18
# 2862430    35  300408.SZ    20180830  25.19  25.19  24.22  24.49      25.10
#
#          change  pct_change        vol       amount  indu  \
# 6164962    0.33      1.9100   71795.44  124613.6430  商贸代理
# 2580455   -0.38     -1.0200    5741.09   21160.9992  环境保护
# 3274091   -0.05     -0.8600  112468.35   65272.9430    造纸
# 3429061   -0.27     -4.0300    4751.50    3131.0125  工程机械
# 6733531    0.02      0.2700    6707.10    4918.3220   钢加工
# 6469851    0.01      0.2000  183452.35   94718.4830   摩托车
# 4645807   -0.27     -4.7900  172637.10   95496.8550    服饰
# 2168133    0.29      1.2200   96913.04  235121.3188   中成药
# 4610506    0.11      0.9800  786464.45  878342.5250  超市连锁
# 2862430   -0.61     -2.4303   79050.89  194122.8510   元器件
#
#                           indu_en
# 6164962            Business agent
# 2580455  Environmental protection
# 3274091               papermaking
# 3429061     Engineering machinery
# 6733531          Steel processing
# 6469851                motorcycle
# 4645807                   apparel
# 2168133          Chinese medicine
# 4610506         Supermarket chain
# 2862430                components

# %%
grouped_stock = list(data_df.groupby("ts_code"))

# %%
data_df["o_h"] = (data_df.high - data_df.open)
data_df["o_c"] = (data_df.close - data_df.open)
data_df["o_l"] = (data_df.low - data_df.open)
data_df["h_c"] = (data_df.close - data_df.high)
data_df["l_c"] = (data_df.close - data_df.low)
data_df["l_h"] = (data_df.high - data_df.low)

# %%
data_df["oh_p"] = data_df.o_h/data_df.l_h
data_df["oc_p"] = data_df.o_c/data_df.l_h
data_df["ol_p"] = data_df.o_l/data_df.l_h
data_df["hc_p"] = data_df.h_c/data_df.l_h
data_df["lc_p"] = data_df.l_c/data_df.l_h

# %%
data_df = data_df[["sn","ts_code","trade_date","oc_p","ol_p","lc_p","oc_p","hc_p","pct_change"]]

# %%
data_df.head(10)
# Out:
#    sn    ts_code  trade_date      oc_p      ol_p      lc_p      oc_p  \
# 0   0  603208.SH    20181026  0.172414 -0.413793  0.586207  0.172414
# 1   1  603208.SH    20181025  0.218182 -0.436364  0.654545  0.218182
# 2   2  603208.SH    20181024 -0.068182 -0.181818  0.113636 -0.068182
# 3   3  603208.SH    20181023 -0.461538 -0.897436  0.435897 -0.461538
# 4   4  603208.SH    20181022  0.759259 -0.037037  0.796296  0.759259
# 5   5  603208.SH    20181019  0.575000 -0.250000  0.825000  0.575000
# 6   6  603208.SH    20181018  0.355556 -0.622222  0.977778  0.355556
# 7   7  603208.SH    20181017 -0.156250 -0.984375  0.828125 -0.156250
# 8   8  603208.SH    20181016 -0.605263 -1.000000  0.394737 -0.605263
# 9   9  603208.SH    20181015  0.058824 -0.602941  0.661765  0.058824
#
#        hc_p  pct_change
# 0 -0.413793      0.9291
# 1 -0.345455     -2.1531
# 2 -0.886364     -0.8539
# 3 -0.564103     -0.8467
# 4 -0.203704      4.5231
# 5 -0.175000      1.4464
# 6 -0.022222     -0.4469
# 7 -0.171875      0.7000
# 8 -0.605263     -2.7237
# 9 -0.338235     -1.9552

# %%
ts_code_ct = data_df.groupby("ts_code").count()[["sn"]]

# %%
ts_code_ct["sn_ct"] = ts_code_ct.sn.apply(lambda x:x>30)

# %%
ts_code_ct.sample(5)
# Out:
#              sn  sn_ct
# ts_code
# 002889.SZ   303   True
# 002322.SZ  2016   True
# 601952.SH   356   True
# 000861.SZ  4000   True
# 603197.SH   352   True

# %%
ts_code_ct = ts_code_ct.sort_values(by = "sn",ascending=False)

# %%
valid_ts_code = ts_code_ct[ts_code_ct.sn_ct]

# %%
valid_ts_code.tail(5)
# Out:
#            sn  sn_ct
# ts_code
# 603590.SH  39   True
# 002933.SZ  38   True
# 603192.SH  38   True
# 601068.SH  35   True
# 002935.SZ  34   True

# %%
first = data_df.reset_index().groupby("ts_code").first()[["index"]].rename(columns={"index":"first"})
last = data_df.reset_index().groupby("ts_code").last()[["index"]].rename(columns={"index":"last"})

# %%
valid_ts_code = valid_ts_code.join(first).join(last)

# %%
valid_ts_code.head()
# Out:
#              sn  sn_ct    first     last
# ts_code
# 000001.SZ  4000   True  4128141  4132140
# 600097.SH  4000   True  1276082  1280081
# 600112.SH  4000   True  2742589  2746588
# 600111.SH  4000   True  5101362  5105361
# 600110.SH  4000   True  2281116  2285115

# %%
dict(valid_ts_code.loc["600112.SH"])
# Out:
# {'first': 2742589, 'last': 2746588, 'sn': 4000, 'sn_ct': True}

# %%
from torch.utils.data import DataLoader,Dataset
from torch.nn.utils import rnn
import math
import numpy as np
import torch
from ray.matchbox import DF_Dataset,Trainer

# %%
def x_pre_row(loc,stop):
    basic = data_df[loc["first"]:loc["first"]+stop]
    arr = basic[["oc_p","ol_p","lc_p","oc_p","hc_p"]].values
    arr_x,arr_y = arr[:-5,:],arr[-5:,:]
    return torch.FloatTensor(arr_x),torch.FloatTensor(arr_y)
    
def x_pre(df):
    res_x,res_y = [],[]
    for i in range(len(df.index)):
        idx = df.index[i]
        loc_dict = dict(df.loc[idx])
        if i== 0:
            maxlen = loc_dict["last"]-loc_dict["first"]
            stop = min(maxlen,800)-int(np.random.rand()*.3*min(maxlen,800))
        x,y = x_pre_row(loc_dict,stop)
        res_x.append(x)
        res_y.append(y)
    tensor_x = rnn.pad_sequence(res_x,batch_first=True,)
    tensor_y = rnn.pad_sequence(res_y,batch_first=True)
    return tensor_x,tensor_y

def stock_collate(batch):
    arrs,_ = zip(*batch)
    arrs_x,arrs_y = zip(*arrs)
#     print(arrs_x)
    return arrs_x,arrs_y

# %%
ds = DF_Dataset(valid_ts_code,x_pre,lambda x:0,bs=12,shuffle=False)

# %%
dl = DataLoader(ds,batch_size=1,shuffle=True,collate_fn=stock_collate)

# %%
gen = iter(dl)
for i in range(1):
    x,y = next(gen)
    print(x[0],y[0])
# Out:
# tensor([[[-0.2826, -0.2826, -0.6304,  ..., -0.2826, -0.2826, -0.6522],
#          [ 0.4894,  0.4894, -0.4043,  ...,  0.4894,  0.4894, -0.1064],
#          [ 0.2286,  0.2286, -0.3143,  ...,  0.2286,  0.2286, -0.4571],
#          ...,
#          [ 0.6190,  0.6190, -0.2262,  ...,  0.6190,  0.6190, -0.1548],
#          [ 0.1400,  0.1400, -0.1500,  ...,  0.1400,  0.1400, -0.7100],
#          [-0.1717, -0.1717, -0.6970,  ..., -0.1717, -0.1717, -0.4747]],
#
#         [[ 0.2500,  0.2500, -0.2727,  ...,  0.2500,  0.2500, -0.4773],
#          [ 0.1702,  0.1702, -0.3298,  ...,  0.1702,  0.1702, -0.5000],
#          [-0.2323, -0.2323, -0.3939,  ..., -0.2323, -0.2323, -0.8384],
#          ...,
#          [ 0.6824,  0.6824, -0.2471,  ...,  0.6824,  0.6824, -0.0706],
#          [-0.0400, -0.0400, -0.5333,  ..., -0.0400, -0.0400, -0.5067],
#          [-0.6548, -0.6548, -0.8333,  ..., -0.6548, -0.6548, -0.8214]],
#
#         [[-0.7857, -0.7857, -0.7857,  ..., -0.7857, -0.7857, -1.0000],
#          [ 0.1111,  0.1111, -0.8889,  ...,  0.1111,  0.1111,  0.0000],
#          [-1.0000, -1.0000, -1.0000,  ..., -1.0000, -1.0000, -1.0000],
#          ...,
#          [-0.2759, -0.2759, -1.0000,  ..., -0.2759, -0.2759, -0.2759],
#          [ 0.4500,  0.4500, -0.3500,  ...,  0.4500,  0.4500, -0.2000],
#          [-0.1667, -0.1667, -0.7083,  ..., -0.1667, -0.1667, -0.4583]],
#
#         ...,
#
#         [[ 0.6250,  0.6250, -0.0417,  ...,  0.6250,  0.6250, -0.3333],
#          [ 0.6875,  0.6875, -0.1042,  ...,  0.6875,  0.6875, -0.2083],
#          [ 0.5185,  0.5185, -0.3704,  ...,  0.5185,  0.5185, -0.1111],
#          ...,
#          [ 0.3690,  0.3690,  0.0000,  ...,  0.3690,  0.3690, -0.6310],
#          [-0.8322, -0.8322, -0.8322,  ..., -0.8322, -0.8322, -1.0000],
#          [ 0.2500,  0.2500, -0.4167,  ...,  0.2500,  0.2500, -0.3333]],
#
#         [[ 0.1154,  0.1154, -0.6538,  ...,  0.1154,  0.1154, -0.2308],
#          [ 0.8182,  0.8182, -0.0909,  ...,  0.8182,  0.8182, -0.0909],
#          [ 0.8750,  0.8750, -0.1250,  ...,  0.8750,  0.8750,  0.0000],
#          ...,
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan],
#          [    nan,     nan,     nan,  ...,     nan,     nan,     nan]],
#
#         [[ 0.4286,  0.4286, -0.1429,  ...,  0.4286,  0.4286, -0.4286],
#          [ 0.7333,  0.7333, -0.2667,  ...,  0.7333,  0.7333,  0.0000],
#          [ 0.4545,  0.4545, -0.3636,  ...,  0.4545,  0.4545, -0.1818],
#          ...,
#          [-0.3043, -0.3043, -0.9565,  ..., -0.3043, -0.3043, -0.3478],
#          [ 0.3889,  0.3889,  0.0000,  ...,  0.3889,  0.3889, -0.6111],
#          [-0.3571, -0.3571, -0.8214,  ..., -0.3571, -0.3571, -0.5357]]]) tensor([[[-0.8375, -0.8375, -0.8750,  0.0375, -0.8375, -0.8375, -0.9625],
#          [-0.1704, -0.1704, -0.5333,  0.3630, -0.1704, -0.1704, -0.6370],
#          [ 0.2025,  0.2025, -0.5506,  0.7532,  0.2025,  0.2025, -0.2468],
#          [ 0.5824,  0.5824, -0.2647,  0.8471,  0.5824,  0.5824, -0.1529],
#          [-0.7122, -0.7122, -1.0000,  0.2878, -0.7122, -0.7122, -0.7122]],
#
#         [[ 0.0652,  0.0652, -0.7609,  0.8261,  0.0652,  0.0652, -0.1739],
#          [ 0.0549,  0.0549, -0.2088,  0.2637,  0.0549,  0.0549, -0.7363],
#          [ 0.6870,  0.6870, -0.0696,  0.7565,  0.6870,  0.6870, -0.2435],
#          [ 0.3220,  0.3220, -0.3220,  0.6441,  0.3220,  0.3220, -0.3559],
#          [-0.1000, -0.1000, -0.4667,  0.3667, -0.1000, -0.1000, -0.6333]],
#
#         [[ 0.6970,  0.6970, -0.2424,  0.9394,  0.6970,  0.6970, -0.0606],
#          [ 0.2632,  0.2632, -0.2632,  0.5263,  0.2632,  0.2632, -0.4737],
#          [-0.2381, -0.2381, -0.6190,  0.3810, -0.2381, -0.2381, -0.6190],
#          [-0.6667, -0.6667, -0.7917,  0.1250, -0.6667, -0.6667, -0.8750],
#          [ 0.1556,  0.1556, -0.7778,  0.9333,  0.1556,  0.1556, -0.0667]],
#
#         [[ 0.4118,  0.4118, -0.0735,  0.4853,  0.4118,  0.4118, -0.5147],
#          [-0.2941, -0.2941, -0.8824,  0.5882, -0.2941, -0.2941, -0.4118],
#          [ 0.3191,  0.3191, -0.5532,  0.8723,  0.3191,  0.3191, -0.1277],
#          [ 0.3269,  0.3269, -0.1346,  0.4615,  0.3269,  0.3269, -0.5385],
#          [ 0.5091,  0.5091, -0.1455,  0.6545,  0.5091,  0.5091, -0.3455]],
#
#         [[ 0.9476,  0.9476, -0.0476,  0.9952,  0.9476,  0.9476, -0.0048],
#          [-0.9139, -0.9139, -0.9139,  0.0000, -0.9139, -0.9139, -1.0000],
#          [-0.7844, -0.7844, -1.0000,  0.2156, -0.7844, -0.7844, -0.7844],
#          [-0.3633, -0.3633, -0.6531,  0.2898, -0.3633, -0.3633, -0.7102],
#          [ 0.4913,  0.4913, -0.0346,  0.5260,  0.4913,  0.4913, -0.4740]],
#
#         [[-0.7381, -0.7381, -0.7857,  0.0476, -0.7381, -0.7381, -0.9524],
#          [ 0.0000,  0.0000, -0.6667,  0.6667,  0.0000,  0.0000, -0.3333],
#          [ 0.7568,  0.7568, -0.0811,  0.8378,  0.7568,  0.7568, -0.1622],
#          [-0.1176, -0.1176, -0.5882,  0.4706, -0.1176, -0.1176, -0.5294],
#          [ 0.3103,  0.3103, -0.4483,  0.7586,  0.3103,  0.3103, -0.2414]],
#
#         [[-0.5294, -0.5294, -0.8039,  0.2745, -0.5294, -0.5294, -0.7255],
#          [-0.8511, -0.8511, -0.9574,  0.1064, -0.8511, -0.8511, -0.8936],
#          [ 0.1111,  0.1111, -0.2444,  0.3556,  0.1111,  0.1111, -0.6444],
#          [ 0.6809,  0.6809,  0.0000,  0.6809,  0.6809,  0.6809, -0.3191],
#          [-0.5128, -0.5128, -0.7436,  0.2308, -0.5128, -0.5128, -0.7692]],
#
#         [[ 0.3953,  0.3953, -0.4651,  0.8605,  0.3953,  0.3953, -0.1395],
#          [-0.6094, -0.6094, -0.9062,  0.2969, -0.6094, -0.6094, -0.7031],
#          [ 0.8947,  0.8947,  0.0000,  0.8947,  0.8947,  0.8947, -0.1053],
#          [ 0.4400,  0.4400, -0.1000,  0.5400,  0.4400,  0.4400, -0.4600],
#          [-0.4651, -0.4651, -0.5349,  0.0698, -0.4651, -0.4651, -0.9302]],
#
#         [[-0.5000, -0.5000, -0.5625,  0.0625, -0.5000, -0.5000, -0.9375],
#          [ 0.0755,  0.0755, -0.2830,  0.3585,  0.0755,  0.0755, -0.6415],
#          [ 0.3293,  0.3293, -0.4878,  0.8171,  0.3293,  0.3293, -0.1829],
#          [ 1.0000,  1.0000,  0.0000,  1.0000,  1.0000,  1.0000,  0.0000],
#          [-0.2364, -0.2364, -0.4909,  0.2545, -0.2364, -0.2364, -0.7455]],
#
#         [[ 0.1500,  0.1500, -0.1500,  0.3000,  0.1500,  0.1500, -0.7000],
#          [ 0.0588,  0.0588, -0.4000,  0.4588,  0.0588,  0.0588, -0.5412],
#          [ 0.7984,  0.7984, -0.0968,  0.8952,  0.7984,  0.7984, -0.1048],
#          [ 0.6038,  0.6038,  0.0000,  0.6038,  0.6038,  0.6038, -0.3962],
#          [ 0.0559,  0.0559, -0.0683,  0.1242,  0.0559,  0.0559, -0.8758]],
#
#         [[    nan,     nan,     nan,     nan,     nan,     nan,     nan],
#          [    nan,     nan,     nan,     nan,     nan,     nan,     nan],
#          [    nan,     nan,     nan,     nan,     nan,     nan,     nan],
#          [    nan,     nan,     nan,     nan,     nan,     nan,     nan],
#          [    nan,     nan,     nan,     nan,     nan,     nan,     nan]],
#
#         [[-0.8974, -0.8974, -0.9744,  0.0769, -0.8974, -0.8974, -0.9231],
#          [ 0.6364,  0.6364, -0.1364,  0.7727,  0.6364,  0.6364, -0.2273],
#          [ 0.5455,  0.5455,  0.0000,  0.5455,  0.5455,  0.5455, -0.4545],
#          [-0.5517, -0.5517, -0.8966,  0.3448, -0.5517, -0.5517, -0.6552],
#          [ 0.5854,  0.5854, -0.3415,  0.9268,  0.5854,  0.5854, -0.0732]]])

# %%
from torch import nn
CUDA = torch.cuda.is_available()
print("with_gpu",CUDA)
# Out:
# with_gpu True

# %%
DIM = 512
N_LAYER = 1
class money1(nn.Module):
    def __init__(self):
        super(money1,self).__init__()
        self.encoder = nn.LSTM(input_size = 7,
#         self.rnn = nn.GRU(input_size=7,
                          hidden_size = DIM,
                          batch_first = True)
        self.decoder = nn.LSTM(input_size = DIM,
                          hidden_size = 7,
                          batch_first = True)
        self.relu = nn.ReLU()
        
    def decode(self,x):
        x = self.decoder(x,self.h_n,self.c_n)
        return x
    
    def forward(self,x):
#         output, h_n = self.rnn(x)
        output, (h_n,c_n) = self.rnn(x)
    
        return output, (h_n,c_n)

# %%
Money = money1()
if CUDA:
    torch.cuda.empty_cache()
    Money.cuda()

# %%
from torch.optim import Adam
opt = Adam(Money.parameters(),lr=1e-4)
loss_f = nn.MSELoss()

def action(*args,**kwargs):
    x,y = args[0]
    opt.zero_grad()
    loss = torch.zeros(1)
    if CUDA: 
        x,y = tuple(va[0].cuda() for va in (x,y))
        loss = loss.cuda()
    else:
        x,y = tuple(va[0] for va in (x,y))
    output, (h_n,c_n) = Money(x)
    output = output[:,-1:,:]
    inputs = []
    has_y = (type(y)==type(x))
        
    for i in range(5):
        input_ = Money.mlp(output.squeeze(1)).unsqueeze(1)
        if i>0:
            loss += loss_f(input_,y[:,i:i+1,:]) #BPTT
            inputs.append(input_)
#             output, h_n = self.rnn(input_, h_n)
            output, (h_n, c_n) = Money.rnn(input_, (h_n, c_n))
        input_ = Money.mlp(output.squeeze(1)).unsqueeze(1)
        loss += loss_f(input_,y[:,i:i+1,:]) #BPTT
        inputs.append(input_)
        result = torch.cat(inputs,dim=1)

    loss.backward()
#     torch.nn.utils.clip_grad_norm_(Money.parameters(),.02)
    opt.step()
    return {"loss":loss.item()}

def val_action(*args,**kwargs):
    x,y = args[0]
    if CUDA: 
        x,y = tuple(va[0].cuda() for va in (x,y))
    else:
        x,y = tuple(va[0] for va in (x,y))
    y_,loss = Money(x,y)
    return {"loss":loss.item()}

trainer = Trainer(ds,batch_size=1,shuffle=True,print_on=5)
trainer.train_data.collate_fn = stock_collate
trainer.action = action
trainer.val_action = val_action
trainer.train(1)
# Out:
#   0%|          | 0/296 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#   0%|          | 1/296 [00:00<00:47,  6.25it/s]
#
#
#
#
#
#
#
#   1%|          | 2/296 [00:00<00:47,  6.20it/s]
#
#
#
#
#
#
#
#   1%|▏         | 4/296 [00:00<00:38,  7.67it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_4]	loss	nan:   1%|▏         | 4/296 [00:00<00:48,  6.04it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_4]	loss	nan:   2%|▏         | 5/296 [00:00<00:38,  7.54it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_4]	loss	nan:   2%|▏         | 6/296 [00:00<00:38,  7.47it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_4]	loss	nan:   2%|▏         | 7/296 [00:00<00:39,  7.35it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_4]	loss	nan:   3%|▎         | 9/296 [00:01<00:36,  7.94it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_9]	loss	nan:   3%|▎         | 9/296 [00:01<00:41,  6.90it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_9]	loss	nan:   3%|▎         | 10/296 [00:01<00:37,  7.65it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_9]	loss	nan:   4%|▎         | 11/296 [00:01<00:37,  7.56it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_9]	loss	nan:   4%|▍         | 12/296 [00:01<00:38,  7.43it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_9]	loss	nan:   4%|▍         | 13/296 [00:01<00:38,  7.35it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_9]	loss	nan:   5%|▍         | 14/296 [00:01<00:38,  7.30it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_14]	loss	nan:   5%|▍         | 14/296 [00:02<00:41,  6.82it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_14]	loss	nan:   5%|▌         | 15/296 [00:02<00:38,  7.30it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_14]	loss	nan:   5%|▌         | 16/296 [00:02<00:38,  7.24it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_14]	loss	nan:   6%|▌         | 17/296 [00:02<00:37,  7.35it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_14]	loss	nan:   6%|▋         | 19/296 [00:02<00:36,  7.56it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_19]	loss	nan:   6%|▋         | 19/296 [00:02<00:38,  7.18it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_19]	loss	nan:   7%|▋         | 20/296 [00:02<00:36,  7.56it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_19]	loss	nan:   7%|▋         | 21/296 [00:02<00:36,  7.50it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_19]	loss	nan:   7%|▋         | 22/296 [00:02<00:36,  7.41it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_19]	loss	nan:   8%|▊         | 23/296 [00:03<00:37,  7.35it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_19]	loss	nan:   8%|▊         | 24/296 [00:03<00:37,  7.34it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_24]	loss	nan:   8%|▊         | 24/296 [00:03<00:38,  7.03it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_24]	loss	nan:   8%|▊         | 25/296 [00:03<00:37,  7.32it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_24]	loss	nan:   9%|▉         | 26/296 [00:03<00:37,  7.25it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_24]	loss	nan:   9%|▉         | 28/296 [00:03<00:36,  7.43it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_24]	loss	nan:  10%|▉         | 29/296 [00:03<00:36,  7.37it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_29]	loss	nan:  10%|▉         | 29/296 [00:04<00:37,  7.10it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_29]	loss	nan:  10%|█         | 30/296 [00:04<00:36,  7.34it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_29]	loss	nan:  10%|█         | 31/296 [00:04<00:36,  7.32it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_29]	loss	nan:  11%|█         | 32/296 [00:04<00:36,  7.27it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_29]	loss	nan:  11%|█         | 33/296 [00:04<00:36,  7.25it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_29]	loss	nan:  11%|█▏        | 34/296 [00:04<00:36,  7.25it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_34]	loss	nan:  11%|█▏        | 34/296 [00:04<00:37,  7.03it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_34]	loss	nan:  12%|█▏        | 35/296 [00:04<00:36,  7.24it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_34]	loss	nan:  12%|█▏        | 36/296 [00:04<00:35,  7.25it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_34]	loss	nan:  12%|█▎        | 37/296 [00:05<00:35,  7.26it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_34]	loss	nan:  13%|█▎        | 38/296 [00:05<00:35,  7.25it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_34]	loss	nan:  13%|█▎        | 39/296 [00:05<00:35,  7.25it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_39]	loss	nan:  13%|█▎        | 39/296 [00:05<00:36,  7.05it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_39]	loss	nan:  14%|█▎        | 40/296 [00:05<00:35,  7.23it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_39]	loss	nan:  14%|█▍        | 41/296 [00:05<00:35,  7.23it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_39]	loss	nan:  14%|█▍        | 42/296 [00:05<00:35,  7.24it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_39]	loss	nan:  15%|█▍        | 44/296 [00:06<00:34,  7.28it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_44]	loss	nan:  15%|█▍        | 44/296 [00:06<00:35,  7.08it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_44]	loss	nan:  15%|█▌        | 45/296 [00:06<00:34,  7.24it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_44]	loss	nan:  16%|█▌        | 46/296 [00:06<00:34,  7.24it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_44]	loss	nan:  16%|█▌        | 47/296 [00:06<00:34,  7.22it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_44]	loss	nan:  16%|█▌        | 48/296 [00:06<00:34,  7.20it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_44]	loss	nan:  17%|█▋        | 49/296 [00:06<00:34,  7.20it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_49]	loss	nan:  17%|█▋        | 49/296 [00:06<00:35,  7.03it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_49]	loss	nan:  17%|█▋        | 50/296 [00:06<00:34,  7.17it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_49]	loss	nan:  17%|█▋        | 51/296 [00:07<00:34,  7.15it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_49]	loss	nan:  18%|█▊        | 52/296 [00:07<00:34,  7.16it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_49]	loss	nan:  18%|█▊        | 53/296 [00:07<00:33,  7.19it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_54]	loss	nan:  18%|█▊        | 53/296 [00:07<00:34,  7.02it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_54]	loss	nan:  19%|█▊        | 55/296 [00:07<00:33,  7.28it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_54]	loss	nan:  19%|█▉        | 56/296 [00:07<00:32,  7.29it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_54]	loss	nan:  19%|█▉        | 57/296 [00:07<00:32,  7.27it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_54]	loss	nan:  20%|█▉        | 58/296 [00:08<00:32,  7.25it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_54]	loss	nan:  20%|█▉        | 59/296 [00:08<00:32,  7.24it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_59]	loss	nan:  20%|█▉        | 59/296 [00:08<00:33,  7.10it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_59]	loss	nan:  20%|██        | 60/296 [00:08<00:32,  7.22it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_59]	loss	nan:  21%|██        | 61/296 [00:08<00:32,  7.22it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_59]	loss	nan:  21%|██        | 62/296 [00:08<00:32,  7.20it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_59]	loss	nan:  21%|██▏       | 63/296 [00:08<00:32,  7.20it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_59]	loss	nan:  22%|██▏       | 64/296 [00:08<00:32,  7.21it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_64]	loss	nan:  22%|██▏       | 64/296 [00:09<00:32,  7.09it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_64]	loss	nan:  22%|██▏       | 65/296 [00:09<00:32,  7.19it/s]
#
#
#
#
#
#
#
# ⭐[ep_0_i_64]	loss	nan:  22%|██▏       | 66/296 [00:09<00:32,  7.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-6c9981cd13c4> in <module>()
#      47 trainer.action = action
#      48 trainer.val_action = val_action
# ---> 49 trainer.train(1)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/ray/matchbox.py in train(self, epochs, name, log_addr)
#     106         for epoch in range(epochs):
#     107             self.track[epoch]=list()
# --> 108             self.run(epoch)
#     109         if self.is_log:
#     110             os.system("mkdir -p %s"%(log_addr))
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/ray/matchbox.py in run(self, epoch)
#     126         for i in t:
#     127
# --> 128             ret = self.action(next(self.train_gen),epoch=epoch,ite=i)
#     129             ret.update({"epoch":epoch,
#     130                         "iter":i,
#
# <ipython-input-49-6c9981cd13c4> in action(*args, **kwargs)
#      29         result = torch.cat(inputs,dim=1)
#      30
# ---> 31     loss.backward()
#      32 #     torch.nn.utils.clip_grad_norm_(Money.parameters(),.02)
#      33     opt.step()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
x[0].size()
# Out:
# torch.Size([12, 623, 7])

# %%
Money.rnn(x[0][:,:,:].cuda())
# Out:
# (tensor([[[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          ...,
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]]], device='cuda:0'),
#  (tensor([[[nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            ...,
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.]]], device='cuda:0'),
#   tensor([[[nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            ...,
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.]]], device='cuda:0')))

# %%
Money.mlp(Money.rnn(x[0].cuda())[0][:,-1:,:].squeeze(1))
# Out:
# tensor([[nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.],
#         [nan., nan., nan., nan., nan., nan., nan.]], device='cuda:0')

# %%
Money.rnn(x[0].cuda())[0][:,-1:,:].size()
# Out:
# torch.Size([12, 1, 512])

# %%
Money(x[0].cuda())
# Out:
# (tensor([[[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          ...,
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]],
#
#          [[nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           ...,
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.],
#           [nan., nan., nan.,  ..., nan., nan., nan.]]], device='cuda:0'),
#  (tensor([[[nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            ...,
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.]]], device='cuda:0'),
#   tensor([[[nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            ...,
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.],
#            [nan., nan., nan.,  ..., nan., nan., nan.]]], device='cuda:0')))
