# %% [markdown]
# # How Machine Learns To Read

# %% [markdown]
# How to use machine to read through human language

# %% [markdown]
# #### Requirements beyond anaconda3 (python libraries, run pip or pip3 to install them)
#
# * tensorflow
# * keras
# * pinyin
# * jieba
# * bcolz

# %% [markdown]
# ### Download the data
#
# The [ctrip hotel comment dataset](http://45.76.223.58/hotel.csv), click the link to download.

# %% [markdown]
# ### Settings

# %%
TASK = "hotel"
TAG_FIELD = "status"
SEQ_LEN = 100 # sequence length, less than this we pad, more than this we drop
LABEL_LEN = 2
CHAR_SIZE = 3000
FACTOR_NB = 30
TK_VOCAB_SIZE = 3000
CN_VOCAB_SIZE = 2000
PY_VOCAB_SIZE = 50

# %% [markdown]
# ## Take a look at the data

# %%
nlp_df = pd.read_csv("http://45.76.223.58/hotel.csv")
nlp_df = pd.read_csv("/data/hotel.csv")
nlp_df.sample(10) # sample 10 lines and their labels
# Out:
#                                                   hotel status
# 774   我是看了点评才入住海景嘉福的，感觉还不如怡东。服务并不好。房间内通风不好有异味。也没看到有送...   GOOD
# 3577  该洒店设施不全且不洁净,让客户感觉不太敢放心使用,且服务人员态度不是太好,早上入住客人收拾房...   EVIL
# 1178                             酒店整体感觉还行,但是地毯不干净,需要清洗.   GOOD
# 2419  真的很差，本来是为了考试离考点近一点才住的，基本上没有服务，房间阴暗一股怪味，本来定的是大床...   EVIL
# 4255  房价非常贵,几乎没有房间可以看到对岸的象鼻山.送的水果饼干又少又不好吃.装修很低档的,离市区...   EVIL
# 2765  这是我在携程遇到过的最差的酒店，问题多多1.这大冷天的。房间塑钢窗密封性极差，四处漏风，第二...   EVIL
# 1565        酒店房间太小了性价比不是很好,不过越靠北越是这样,没有办法啊,还是南方的酒店性价比好!   GOOD
# 2272  我非常不满意新月阁客栈，如果有零分可以选，我宁可一分也不肯给.他们的服务太差了.明明含早餐的...   EVIL
# 3430      不愧是westin，房间就不用说了，游泳池啊room service都很不错！卫生间很大！   GOOD
# 3438  这是第一次订这家酒店，酒店位置还可以，但肯定开业已经有一段年月，装修有点旧，办了入住手续，进...   EVIL

# %%
lines = list(nlp_df[TASK])

len_lines=len(lines)

from jieba import cut
from multiprocessing import Pool

# google python multiprocessing

def cutline(line):
    return "|".join(list(cut(str(line))))

def cutline_l(line):
    return list(cut(str(line)))

# %%
p=Pool(6)

# %%
# %time shards=p.map(cutline,lines)
# Out:
# CPU times: user 50.2 ms, sys: 27.9 ms, total: 78.1 ms
# Wall time: 8.11 s

# %%
# %time shards_list=p.map(cutline_l,lines)
# Out:
# CPU times: user 223 ms, sys: 65.9 ms, total: 289 ms
# Wall time: 6.97 s

# %%
# %time token_list=("|".join(shards)).split("|")
# Out:
# CPU times: user 35.2 ms, sys: 19.5 ms, total: 54.7 ms
# Wall time: 54.8 ms

# %%
from collections import Counter

# 统计词频

token_counter=Counter(token_list)
token_w=list(token_counter.keys())
token_c=list(token_counter.values())

# %%
token_df=pd.DataFrame({"token":token_w,"count":token_c}).sort_values(by="count",ascending=False)

# %%
token_df
# Out:
#        count  token
# 10     30629      ，
# 7      20237      的
# 44     12430      。
# 52      7685      了
# 23      7356      ,
# 9       6262     酒店
# 3       5780      是
# 235     4792      我
# 304     4497
# 14      4451     房间
# 21      3786      很
# 20      3311      ！
# 134     3193      在
# 42      3149      也
# 27      3101      .
# 146     2513      不
# 68      2456      有
# 296     2371      都
# 263     2256     没有
# 74      2202      还
# 76      2106      就
# 5       2088      住
# 110     2020     服务
# 4       1864     我们
# 26      1740     不错
# 30      1737      好
# 212     1700     入住
# 111     1657      和
# 215     1626      说
# 260     1603      到
# ...      ...    ...
# 13284      1     两把
# 13286      1   海鲜酒楼
# 13287      1  59HKD
# 13254      1     真给
# 13252      1     前晚
# 13211      1     过大
# 13235      1     心脏
# 13212      1     人上
# 13213      1   High
# 13217      1    欢迎词
# 13219      1     官宦
# 13222      1     呕吐
# 13224      1     发冷
# 13225      1     开药
# 13226      1   黄莲素片
# 13229      1   食品卫生
# 13231      1     早日
# 13237      1   身体状况
# 13251      1     出嫁
# 994        1     园内
# 993        1  money
# 13240      1     增添
# 13241      1     自出
# 13242      1     倍受
# 13244      1     宏都
# 13245      1     员到
# 13246      1     日定
# 992        1     带足
# 981        1     太潮
# 23258      1      延
#
# [23259 rows x 2 columns]

# %% [markdown]
# #### Most frequent used tokens

# %%
token_df.head(20)
# Out:
#      count token
# 10   30629     ，
# 7    20237     的
# 44   12430     。
# 52    7685     了
# 23    7356     ,
# 9     6262    酒店
# 3     5780     是
# 235   4792     我
# 304   4497
# 14    4451    房间
# 21    3786     很
# 20    3311     ！
# 134   3193     在
# 42    3149     也
# 27    3101     .
# 146   2513     不
# 68    2456     有
# 296   2371     都
# 263   2256    没有
# 74    2202     还

# %% [markdown]
# #### Pronounciation Reresentation

# %%
# !!pip install pinyin

# %%
# Pin yin transfer function
import pinyin
def readcn(x):
    return pinyin.get(str(x),format="strip", delimiter=" ").lower()

# %%
len(nlp_df)
# Out:
# 4676

# %%
nlp_df[TASK+"_py"]=nlp_df[TASK].apply(readcn)

nlp_df.sample(10)
# Out:
#                                                   hotel status  \
# 1114  房间小,风格老.特别是服务糟糕.我是3月初住的,当时房间空调吹冷风,跟服务员反映三次都没任何...   EVIL
# 2300  对该酒店不是很满意.预定入住2天.结果入住当日查询无客人姓名.通过协成沟通没问题了以后..再...   EVIL
# 2635  5月初入住这家酒店，只可以用2个字形容“糟糕”，是我见过的最差的5星级，晚上1楼的disco...   EVIL
# 3576  酒店外表及大堂看上去挺好的，本来对它也挺有信心的，而且就在市中心，出行挺方便的，可是从进电梯...   EVIL
# 2566  有那么多朋友点评钻石公寓，不妨再讲两句。钻石新推出的“特价”双人房，其实一点也不特价。以前有...   EVIL
# 2799  几乎是在凌晨才到的包头，包头也没有什么特别好的酒店，每次来了就是住在这家，所以也没有忒多的对...   GOOD
# 3140  离公司较近，所以选择了这家3星酒店餐饮价格很有竞争力，和普通饭店接近。免费注册 网站导航 宾...   GOOD
# 4042  长城酒店的外形很壮观。是嘉峪关里两家四星酒店之一。不过太陈旧了。优点1.离雄关广场走路10分...   GOOD
# 1186  男友是老外第一次来上海所以选择住的离外滩近的酒店，25号入住一切OK，宾馆周围环境不怎么样就...   EVIL
# 784                         感觉挺好的,是家不错的酒店,下个月去办事打算还住那儿.   GOOD
#
#                                                hotel_py  \
# 1114  fang jian xiao , feng ge lao . te bie shi fu w...
# 2300  dui gai jiu dian bu shi hen man yi . yu ding r...
# 2635  5 yue chu ru zhu zhe jia jiu dian ， zhi ke yi ...
# 3576  jiu dian wai biao ji da tang kan shang qu ting...
# 2566  you na yao duo peng you dian ping zuan shi gon...
# 2799  ji hu shi zai ling chen cai dao de bao tou ， b...
# 3140  li gong si jiao jin ， suo yi xuan ze le zhe ji...
# 4042  chang cheng jiu dian de wai xing hen zhuang gu...
# 1186  nan you shi lao wai di yi ci lai shang hai suo...
# 784   gan jue ting hao de , shi jia bu cuo de jiu di...
#
#                                                 tk_list
# 1114  [房间, 小, ,, 风格, 老, ., 特别, 是, 服务, 糟糕, ., 我, 是, 3...
# 2300  [对, 该, 酒店, 不是, 很, 满意, ., 预定, 入住, 2, 天, ., 结果, ...
# 2635  [5, 月初, 入住, 这家, 酒店, ，, 只, 可以, 用, 2, 个, 字, 形容, ...
# 3576  [酒店, 外表, 及, 大堂, 看上去, 挺, 好, 的, ，, 本来, 对, 它, 也, ...
# 2566  [有, 那么, 多, 朋友, 点评, 钻石, 公寓, ，, 不妨, 再, 讲, 两句, 。,...
# 2799  [几乎, 是, 在, 凌晨, 才, 到, 的, 包头, ，, 包头, 也, 没有, 什么, ...
# 3140  [离, 公司, 较近, ，, 所以, 选择, 了, 这家, 3, 星, 酒店, 餐饮, 价格...
# 4042  [长城, 酒店, 的, 外形, 很, 壮观, 。, 是, 嘉峪关, 里, 两家, 四星, 酒...
# 1186  [男友, 是, 老外, 第一次, 来, 上海, 所以, 选择, 住, 的, 离, 外滩, 近...
# 784   [感觉, 挺, 好, 的, ,, 是, 家, 不错, 的, 酒店, ,, 下个月, 去, 办...

# %%
def text2number(col_series,c2i_dict,default_idx):
    final=[]
    for line in list(col_series):
        final.append(list(c2i_dict[lt] if lt in c2i_dict else default_idx for lt in list(cut(str(line)))))
    return np.array(final)

def s2ttl_list(col_series):
    return "".join(list(col_series.apply(lambda x:str(x))))
    
def make_dict(totalist,seq_len,char_size=CHAR_SIZE,namestr="nlp_analysis"):
    tdf=pd.DataFrame(list(totalist),columns=["char"])
    # vocabulary frequency count
    tdf_c=list(pd.crosstab(tdf["char"],columns="char").sort_values(by="char",ascending=False)[:char_size].index.values)

    # Make character to index & index to character
    char2idx = dict((v,k) for k,v in enumerate(tdf_c))
    idx2char = dict((k,v) for k,v in enumerate(tdf_c))
    
    np.save(u"/data/dict/%s_char2idx.npy"%(namestr),char2idx)
    np.save(u"/data/dict/%s_idx2char.npy"%(namestr),idx2char)

    return char2idx,idx2char

def word2array(col_series,char2idx):
    idx_array = sequence.pad_sequences(text2number(col_series=col_series, c2i_dict=char2idx, default_idx=CHAR_SIZE-1),
                                       maxlen=SEQ_LEN,
                                       value=CHAR_SIZE-1
                                      )
    return idx_array

# %% [markdown]
# ### Making and saving dictionary

# %%
import numpy as np

# %%
char2idx_tk,idx2char_tk = make_dict(totalist=token_list,seq_len=SEQ_LEN,
                                    char_size=TK_VOCAB_SIZE,namestr="rcc_%s_tk"%(TASK))
char2idx_cn,idx2char_cn = make_dict(totalist=s2ttl_list(nlp_df[TASK]),seq_len=30,
                                    char_size=CN_VOCAB_SIZE,namestr="rcc_%s_cn"%(TASK))
char2idx_py,idx2char_py = make_dict(totalist=s2ttl_list(nlp_df[TASK+"_py"]),seq_len=50,
                                    char_size=PY_VOCAB_SIZE,namestr="rcc_%s_py"%(TASK))
# Out:
# ============================================================
# Total chars:	3000
# ------------------------------------------------------------
# The first 10 chars :	，的。了,酒店是我 房间
# The last 10 chars :	旧旧关不上酒店客房视野邯郸不吃#油烟味茶叶差得
# ------------------------------------------------------------
# The sequence length:	100
# saving_dict
# ============================================================
# Dictionary Saved To /data/dict/rcc_hotel_tk_char2idx.npy
# Dictionary Saved To /data/dict/rcc_hotel_tk_idx2char.npy
# ============================================================
# ============================================================
# Total chars:	2000
# ------------------------------------------------------------
# The first 10 chars :	，的。不是了一房,店
# The last 10 chars :	碍碎樱爷仁阅钓辈抛径
# ------------------------------------------------------------
# The sequence length:	30
# saving_dict
# ============================================================
# Dictionary Saved To /data/dict/rcc_hotel_cn_char2idx.npy
# Dictionary Saved To /data/dict/rcc_hotel_cn_idx2char.npy
# ============================================================
# ============================================================
# Total chars:	50
# ------------------------------------------------------------
# The first 10 chars :	 inauehgod
# The last 10 chars :	!v）76（；？9“
# ------------------------------------------------------------
# The sequence length:	50
# saving_dict
# ============================================================
# Dictionary Saved To /data/dict/rcc_hotel_py_char2idx.npy
# Dictionary Saved To /data/dict/rcc_hotel_py_idx2char.npy
# ============================================================

# %%
nlp_df["tk_list"]=shards_list

nlp_df
# Out:
#                                                   hotel status  \
# 0        可以这样评价是我们住过的最差的酒店，简陋的大堂，肮脏的房间，可怕的卫生间，绝对是一场恶梦！！   EVIL
# 1                            很安静,隔音设施不错.服务员态度很好,下次还会选这里   GOOD
# 2                很典型的型酒店就是房g很小,l生g也不大。并且设施非常的简陋。空{@得f了些   EVIL
# 3     这样的酒店一般,前台服务员善意提醒预定房间有些吵(靠近高架),因为只有这样的房间才有收费的宽...   EVIL
# 4     因为悦华酒店没房间了才通过携程定泉州酒店的。其实泉酒的整体比悦华大气，装修也很讲究，唯一比不...   GOOD
# 5     简单来讲，房间还好吧，大过万达假日。不过当时冰雪节比较贵，觉得没那么划算。平时哈尔滨这个烂城...   GOOD
# 6     房间设施可以,但空间偏小,客房电梯很特别(没房卡上不去),很适合某些人使用(偷吃)........   GOOD
# 7     酒店真的不怎么样，不知道怎么评上四星的。房间又小又旧，早餐也没什么吃的，服务也不好，而且会有...   EVIL
# 8        房间不是很大，但是卫生间装的很有创意。早餐很好，品种多，而且味道不错，服务人员的态度也很好。   GOOD
# 9     酒店别具一格，很有一些园林风尚。服务非常到位，无论是门童还是前台乃至清洁女工，处处体现热情、...   GOOD
# 10    该酒店虽然价格不高,但服务实在太差,房间例行送的水果和报纸要打电话问才送过来,早餐结束的时间...   EVIL
# 11    服务态度实在是太差了,尤其是楼层的服务员,全是大婶,态度非常的恶劣!洗手间一洗澡全是水,洗脸...   EVIL
# 12                              服务有出错，让人大跌眼镜的那种，房卡会被搞错！   EVIL
# 13    携程提供的160元的普通标间没有任何竞争力,房间设施一般,床单破损,服务也一般.商务豪华标间...   EVIL
# 14    中规中矩的五星级酒店，但酒店双人房床较小，其他还可以，毕竟也是连锁酒店。另外，酒店的大堂确实...   GOOD
# 15    这是一家住宿房间设施极差的度假村，我提前在携程网订了一间5号楼的房间，但是，当我入住时前台因...   EVIL
# 16    几个月之后再次入住，一进门大厅里一位女工作人员就叫得出我的名字，很不一般。服务没得说，酒店位...   GOOD
# 17              房间感觉还可以，但是洗漱用的毛巾浴巾质量不好，感觉没有洗干净，房间隔音效果不好   EVIL
# 18                           很喜欢，而且解放北路也很漂亮，住这里晚上出来散步很好   GOOD
# 19    房间内饰尚新,服务也比较好.稍感不便的地方是坐电梯的时候必须插入门卡.(虽然目的是为了客人的...   GOOD
# 20    经常去海口出差,但从没住过该酒店.看外表感觉一般吧其实酒店里面还真不错,房间是新装修的(我住...   GOOD
# 21    经常入住京伦酒店，感觉还不错。但是3月份去的一次，安排了一个最拐角的房间有一张双人床，服务人...   EVIL
# 22    酒店位置不错，交通方便。硬件环境虽然显得比较旧了，但依旧不失档次。服务态度基本令人满意。宽带...   GOOD
# 23    酒店check in, check out很快；客房服务员态度很热情；餐厅的服务很好，食物也...   GOOD
# 24    酒店虽然有点旧，房间也不大，但贵在干净，地点好，在市中心的中山广场边上，上哪都很方便。早餐比...   GOOD
# 25    我住在6楼,3楼KTV的声音很吵!打电话到大堂投诉居然把电话挂掉就算了......以后肯定不...   EVIL
# 26    基本上是个硬件很差，服务尚可的酒店。入住第一晚，空调出风口没装好，有金属碰撞的声音，不大，但...   EVIL
# 27    国际饭店虽然挂牌3星，但是设施和服务差了一些，而且携程提供的价格不大有竞争力，在另外一个酒店...   EVIL
# 28    我于2008，01，15入住，房间消毒水味很浓，很冷，开了空调，盖两张床的被子还是没点暖意，...   EVIL
# 29                给父母订的~回来说房间远不及盛华的,早餐也不行.唯一好的就是在风景区内了~   EVIL
# ...                                                 ...    ...
# 4646       酒店周边环境不错，对面有大润发购物比较方便，房间还可以，服务也可以，总体性价比还算不错。   GOOD
# 4647  酒店位于福州最热闹的东街口，出来吃饭购物逛街都十分方便。商务单人大床间房间够宽敞，还配有液晶...   GOOD
# 4648              差劲呀，还市中心的酒店呢，上网还要另外接线，４块钱一小时，抢钱啊！！！！！   EVIL
# 4649  酒店硬件来讲应该是不错的，就是位置比较远，离市中心和商业区都不是很方便，去的时候又刚好赶上出...   GOOD
# 4650  地段还不错，但作为一家4星级宾馆，设施方面实在是不敢恭维。主要问题在卫生间。我住的是标间，可...   EVIL
# 4651                            硬件设施太旧挨着大街，环境很吵价格偏高不符4星   EVIL
# 4652  酒店的位置还是不错的，附近就有地铁站可通达各处，从机场过来想省钱的话坐A31就可以了，房间面...   GOOD
# 4653  8月8日晚上到的，到了以后立刻开电视，发现没有信号。10多分钟后保安才上来。打开电视，都已经...   EVIL
# 4654                              房间设备比较陈旧，没五星标准客人非常不满意   EVIL
# 4655  不知道该酒店如何区分大床与标间？？？床和普通标间的床差不多大小，说是商务房间结果安排在一楼，...   EVIL
# 4656  入住11楼大床房，一出电梯就有明显的地毯散发的霉味；房间的窗子不能打开，即便这样，也有蚊子存...   EVIL
# 4657  2007年9月份曾住二晚,总体评价:1、服务还可以，入住的客人特别多，尤其是旅行团的，可能是...   GOOD
# 4658  地理位置不错，因为威海小，所以打车到市区也不用很多钱。我订的是海景房，海景不能说很美，但有日...   GOOD
# 4659                           房间干净整洁，位置也好，就是缺少部电梯，有点遗憾   GOOD
# 4660  酒店从价格来讲还算便宜。但前台有特价房68，而在携程只能顶到98的，这一点我接受不了。酒店服...   EVIL
# 4661  酒店太旧了， 大堂感觉象三星级的， 房间也就是的好点的三星级的条件， 在青岛这样的酒店是绝对...   EVIL
# 4662  为了图交通方便，所以选择了市长大厦。本以为市长大厦是比较新的酒店，可一进门就感觉很失望――大...   EVIL
# 4663  虽然预定比较方便，但是宾馆的对顾客的关怀不足，房间冷得让人睡不着觉服务人员还说暖和的！！！宾...   EVIL
# 4664  在胡同里，不过还算好找。房价便宜，酒店设施简单，但还比较干净，离北京火车站很近，步行都可以。...   EVIL
# 4665  我住的是特色标间，所谓特色，是有些类似家的感觉。寝具不是单调的白色，是条纹和大格子的，感觉很...   GOOD
# 4666  酒店规模大，楼层没有设置服务人员房间，所以找不到服务员；房间较冷（尤其是一层），订时务必要订...   GOOD
# 4667                           济南最好的酒店，服务也不错，难得是还有印度厨师！   GOOD
# 4668                是华苑产业园区唯一的酒店，虽说有3星，但总体感觉也就比快捷酒店好一点。   EVIL
# 4669                        该酒店地段不方便，超难打车，服务不到位，酒店设备有点旧   EVIL
# 4670                       价格和设施还是成正比的。这次给客人预定，反映还是不错的。   GOOD
# 4671  只可惜硬件设施不完备，加上路边的噪音，给本来应是很完美的酒店留下了一点遗憾，希望如家的加盟店...   GOOD
# 4672  传说中的四星挂牌，2星标准，倒也恰当。房间的地毯确实很脏，其他还行啦！卫生纸确实如传说中的少...   EVIL
# 4673  我要的是大床房的，房间超小而且没有桌子，使用宽带也很不方便还要接个东西，拨号的密码也要问了才...   EVIL
# 4674  由于五一当天决定出去玩, 订晚了, 只有三家酒店可选择, 就选了这家.优点: 酒店在青山湖边...   EVIL
# 4675  我们住的是13楼,不过因为是延马路,所以到了晚上还是有很吵的声音,隔音不太好,房间内的设施很...   EVIL
#
#                                                hotel_py  \
# 0     ke yi zhe yang ping jia shi wo men zhu guo de ...
# 1     hen an jing , ge yin she shi bu cuo . fu wu yu...
# 2     hen dian xing de xing jiu dian jiu shi fang g ...
# 3     zhe yang de jiu dian yi ban , qian tai fu wu y...
# 4     yin wei yue hua jiu dian mei fang jian le cai ...
# 5     jian dan lai jiang ， fang jian huan hao ba ， d...
# 6     fang jian she shi ke yi , dan kong jian pian x...
# 7     jiu dian zhen de bu zen yao yang ， bu zhi dao ...
# 8     fang jian bu shi hen da ， dan shi wei sheng ji...
# 9     jiu dian bie ju yi ge ， hen you yi xie yuan li...
# 10    gai jiu dian sui ran jia ge bu gao , dan fu wu...
# 11    fu wu tai du shi zai shi tai cha le , you qi s...
# 12    fu wu you chu cuo ， rang ren da die yan jing d...
# 13    xie cheng ti gong de 1 6 0 yuan de pu tong bia...
# 14    zhong gui zhong ju de wu xing ji jiu dian ， da...
# 15    zhe shi yi jia zhu su fang jian she shi ji cha...
# 16    ji ge yue zhi hou zai ci ru zhu ， yi jin men d...
# 17    fang jian gan jue huan ke yi ， dan shi xi shu ...
# 18    hen xi huan ， er qie jie fang bei lu ye hen pi...
# 19    fang jian nei shi shang xin , fu wu ye bi jiao...
# 20    jing chang qu hai kou chu cha , dan cong mei z...
# 21    jing chang ru zhu jing lun jiu dian ， gan jue ...
# 22    jiu dian wei zhi bu cuo ， jiao tong fang bian ...
# 23    jiu dian c h e c k   i n ,   c h e c k   o u t...
# 24    jiu dian sui ran you dian jiu ， fang jian ye b...
# 25    wo zhu zai 6 lou , 3 lou k t v de sheng yin he...
# 26    ji ben shang shi ge ying jian hen cha ， fu wu ...
# 27    guo ji fan dian sui ran gua pai 3 xing ， dan s...
# 28    wo yu 2 0 0 8 ， 0 1 ， 1 5 ru zhu ， fang jian x...
# 29    gei fu mu ding de ~ hui lai shuo fang jian yua...
# ...                                                 ...
# 4646  jiu dian zhou bian huan jing bu cuo ， dui mian...
# 4647  jiu dian wei yu fu zhou zui re nao de dong jie...
# 4648  cha jing ya ， huan shi zhong xin de jiu dian n...
# 4649  jiu dian ying jian lai jiang ying gai shi bu c...
# 4650  di duan huan bu cuo ， dan zuo wei yi jia 4 xin...
# 4651  ying jian she shi tai jiu ai zhao da jie ， hua...
# 4652  jiu dian de wei zhi huan shi bu cuo de ， fu ji...
# 4653  8 yue 8 ri wan shang dao de ， dao le yi hou li...
# 4654  fang jian she bei bi jiao chen jiu ， mei wu xi...
# 4655  bu zhi dao gai jiu dian ru he qu fen da chuang...
# 4656  ru zhu 1 1 lou da chuang fang ， yi chu dian ti...
# 4657  2 0 0 7 nian 9 yue fen ceng zhu er wan , zong ...
# 4658  di li wei zhi bu cuo ， yin wei wei hai xiao ， ...
# 4659  fang jian gan jing zheng jie ， wei zhi ye hao ...
# 4660  jiu dian cong jia ge lai jiang huan suan bian ...
# 4661  jiu dian tai jiu le ，   da tang gan jue xiang ...
# 4662  wei le tu jiao tong fang bian ， suo yi xuan ze...
# 4663  sui ran yu ding bi jiao fang bian ， dan shi bi...
# 4664  zai hu tong li ， bu guo huan suan hao zhao 。 f...
# 4665  wo zhu de shi te se biao jian ， suo wei te se ...
# 4666  jiu dian gui mo da ， lou ceng mei you she zhi ...
# 4667  ji nan zui hao de jiu dian ， fu wu ye bu cuo ，...
# 4668  shi hua yuan chan ye yuan qu wei yi de jiu dia...
# 4669  gai jiu dian di duan bu fang bian ， chao nan d...
# 4670  jia ge he she shi huan shi cheng zheng bi de 。...
# 4671  zhi ke xi ying jian she shi bu wan bei ， jia s...
# 4672  chuan shuo zhong de si xing gua pai ， 2 xing b...
# 4673  wo yao de shi da chuang fang de ， fang jian ch...
# 4674  you yu wu yi dang tian jue ding chu qu wan ,  ...
# 4675  wo men zhu de shi 1 3 lou , bu guo yin wei shi...
#
#                                                 tk_list
# 0     [可以, 这样, 评价, 是, 我们, 住, 过, 的, 最差, 的, 酒店, ，, 简陋,...
# 1     [很, 安静, ,, 隔音, 设施, 不错, ., 服务员, 态度, 很, 好, ,, 下次...
# 2     [很, 典型, 的, 型, 酒店, 就是, 房, g, 很小, ,, l, 生, g, 也,...
# 3     [这样, 的, 酒店, 一般, ,, 前台, 服务员, 善意, 提醒, 预定, 房间, 有些...
# 4     [因为, 悦华, 酒店, 没, 房间, 了, 才, 通过, 携程, 定, 泉州, 酒店, 的...
# 5     [简单, 来讲, ，, 房间, 还好, 吧, ，, 大过, 万达, 假日, 。, 不过, 当...
# 6     [房间, 设施, 可以, ,, 但, 空间, 偏小, ,, 客房, 电梯, 很, 特别, (...
# 7     [酒店, 真的, 不怎么样, ，, 不, 知道, 怎么, 评, 上, 四星, 的, 。, 房...
# 8     [房间, 不是, 很大, ，, 但是, 卫生间, 装, 的, 很, 有, 创意, 。, 早餐...
# 9     [酒店, 别具一格, ，, 很, 有, 一些, 园林, 风尚, 。, 服务, 非常, 到位,...
# 10    [该, 酒店, 虽然, 价格, 不高, ,, 但, 服务, 实在, 太, 差, ,, 房间,...
# 11    [服务态度, 实在, 是, 太差, 了, ,, 尤其, 是, 楼层, 的, 服务员, ,, ...
# 12    [服务, 有, 出错, ，, 让, 人, 大跌眼镜, 的, 那种, ，, 房卡, 会, 被,...
# 13    [携程, 提供, 的, 160, 元, 的, 普通, 标间, 没有, 任何, 竞争力, ,,...
# 14    [中规中矩, 的, 五星级, 酒店, ，, 但, 酒店, 双人房, 床较, 小, ，, 其他...
# 15    [这是, 一家, 住宿, 房间, 设施, 极差, 的, 度假村, ，, 我, 提前, 在, ...
# 16    [几个, 月, 之后, 再次, 入住, ，, 一, 进门, 大厅, 里, 一位, 女, 工作...
# 17    [房间, 感觉, 还, 可以, ，, 但是, 洗漱, 用, 的, 毛巾, 浴巾, 质量, 不...
# 18    [很, 喜欢, ，, 而且, 解放北路, 也, 很漂亮, ，, 住, 这里, 晚上, 出来,...
# 19    [房间, 内饰, 尚新, ,, 服务, 也, 比较, 好, ., 稍感不便, 的, 地方, ...
# 20    [经常, 去, 海口, 出差, ,, 但, 从没, 住, 过, 该, 酒店, ., 看, 外...
# 21    [经常, 入住, 京伦, 酒店, ，, 感觉, 还, 不错, 。, 但是, 3, 月份, 去...
# 22    [酒店, 位置, 不错, ，, 交通, 方便, 。, 硬件, 环境, 虽然, 显得, 比较,...
# 23    [酒店, check,  , in, ,,  , check,  , out, 很快, ；,...
# 24    [酒店, 虽然, 有点, 旧, ，, 房间, 也, 不大, ，, 但, 贵在, 干净, ，,...
# 25    [我, 住, 在, 6, 楼, ,, 3, 楼, KTV, 的, 声音, 很, 吵, !, ...
# 26    [基本上, 是, 个, 硬件, 很差, ，, 服务, 尚可, 的, 酒店, 。, 入住, 第...
# 27    [国际饭店, 虽然, 挂牌, 3, 星, ，, 但是, 设施, 和, 服务, 差, 了, 一...
# 28    [我于, 2008, ，, 01, ，, 15, 入住, ，, 房间, 消毒水, 味, 很浓...
# 29    [给, 父母, 订, 的, ~, 回来, 说, 房间, 远, 不及, 盛华, 的, ,, 早...
# ...                                                 ...
# 4646  [酒店, 周边环境, 不错, ，, 对面, 有, 大润发, 购物, 比较, 方便, ，, 房...
# 4647  [酒店, 位于, 福州, 最, 热闹, 的, 东街口, ，, 出来, 吃饭, 购物, 逛街,...
# 4648  [差劲, 呀, ，, 还, 市中心, 的, 酒店, 呢, ，, 上网, 还要, 另外, 接线...
# 4649  [酒店, 硬件, 来讲, 应该, 是, 不错, 的, ，, 就是, 位置, 比较, 远, ，...
# 4650  [地段, 还, 不错, ，, 但, 作为, 一家, 4, 星级宾馆, ，, 设施, 方面, ...
# 4651  [硬件, 设施, 太旧, 挨着, 大街, ，, 环境, 很, 吵, 价格, 偏高, 不符, ...
# 4652  [酒店, 的, 位置, 还是, 不错, 的, ，, 附近, 就, 有, 地铁站, 可, 通达...
# 4653  [8, 月, 8, 日, 晚上, 到, 的, ，, 到, 了, 以后, 立刻, 开, 电视,...
# 4654      [房间, 设备, 比较, 陈旧, ，, 没, 五星, 标准, 客人, 非常, 不, 满意]
# 4655  [不, 知道, 该, 酒店, 如何, 区分, 大床, 与, 标间, ？, ？, ？, 床, ...
# 4656  [入住, 11, 楼大床, 房, ，, 一出, 电梯, 就, 有, 明显, 的, 地毯, 散...
# 4657  [2007, 年, 9, 月份, 曾住, 二晚, ,, 总体, 评价, :, 1, 、, 服...
# 4658  [地理位置, 不错, ，, 因为, 威海, 小, ，, 所以, 打车, 到, 市区, 也, ...
# 4659  [房间, 干净, 整洁, ，, 位置, 也好, ，, 就是, 缺少, 部, 电梯, ，, 有...
# 4660  [酒店, 从, 价格, 来讲, 还, 算, 便宜, 。, 但, 前台, 有, 特价, 房, ...
# 4661  [酒店, 太旧, 了, ，,  , 大堂, 感觉, 象, 三星级, 的, ，,  , 房间,...
# 4662  [为了, 图, 交通, 方便, ，, 所以, 选择, 了, 市长, 大厦, 。, 本, 以为...
# 4663  [虽然, 预定, 比较, 方便, ，, 但是, 宾馆, 的, 对, 顾客, 的, 关怀, 不...
# 4664  [在, 胡同, 里, ，, 不过, 还, 算, 好找, 。, 房价, 便宜, ，, 酒店设施...
# 4665  [我, 住, 的, 是, 特色, 标间, ，, 所谓, 特色, ，, 是, 有些, 类似, ...
# 4666  [酒店, 规模, 大, ，, 楼层, 没有, 设置, 服务, 人员, 房间, ，, 所以, ...
# 4667  [济南, 最好, 的, 酒店, ，, 服务, 也, 不错, ，, 难得, 是, 还有, 印度...
# 4668  [是, 华苑, 产业园, 区, 唯一, 的, 酒店, ，, 虽说, 有, 3, 星, ，, ...
# 4669  [该, 酒店, 地段, 不, 方便, ，, 超难, 打车, ，, 服务, 不, 到位, ，,...
# 4670  [价格, 和, 设施, 还是, 成正比, 的, 。, 这次, 给, 客人, 预定, ，, 反...
# 4671  [只, 可惜, 硬件, 设施, 不, 完备, ，, 加上, 路边, 的, 噪音, ，, 给,...
# 4672  [传说, 中, 的, 四星, 挂牌, ，, 2, 星, 标准, ，, 倒, 也, 恰当, 。...
# 4673  [我要, 的, 是, 大床, 房, 的, ，, 房间, 超小, 而且, 没有, 桌子, ，,...
# 4674  [由于, 五一, 当天, 决定, 出去玩, ,,  , 订晚, 了, ,,  , 只有, 三...
# 4675  [我们, 住, 的, 是, 13, 楼, ,, 不过, 因为, 是, 延, 马路, ,, 所...
#
# [4676 rows x 4 columns]

# %%
# train valid seperation point
tv_point = int(len(nlp_df)*.8)

train_df = nlp_df[:tv_point]
valid_df = nlp_df[tv_point:]

len(train_df),len(valid_df)
# Out:
# (3740, 936)

# %%
trn_cn,trn_py,trn_tk,trn_y = train_df[TASK],train_df[TASK+"_py"],train_df["tk_list"],train_df[TAG_FIELD]
val_cn,val_py,val_tk,val_y = valid_df[TASK],valid_df[TASK+"_py"],valid_df["tk_list"],valid_df[TAG_FIELD]

# %%
# !!sudo apt install bcolz

# %%
from tqdm import trange
import os
import bcolz

class nlp_prepro:
    def __init__(self,seq_len,vocab,char2idx,idx2char):
        self.seq_len = seq_len
        self.vocab = vocab
        self.char2idx = char2idx
        self.idx2char = idx2char
        self.pad_blank = np.ones(self.seq_len)*(vocab-1)
        
    def dict_map(self,x):
        try:
            return self.char2idx[x]
        except:
            return self.vocab-1
        
    def charlist2idx(self,charlist):
        return np.vectorize(self.dict_map)(charlist)
    
    def pad_idx(self,x):
        x = self.charlist2idx(x)
        padded = self.pad_blank.copy()
        padded[-min(len(x),self.seq_len):]=x[-self.seq_len:]
        return padded
    
    def split_cn(self,x):
        return list(str(x))
    
    def split_py(self,x):
        return list(str(x).split(" "))
    
    def split_tk(self,x):
        return x
    
    def to_bcolz(self,bc_dir,series,split_func):
        if len(bc_dir)>5:
            os.system("rm -rf %s"%(bc_dir))
        bc = bcolz.carray(np.zeros((0,self.seq_len)),rootdir=bc_dir,dtype="int")
        t=trange(len(series))
        for i in t:
            bc.append(self.pad_idx(split_func(series[i])))
            bc.flush()
        return bc

# %%
cn_pre = nlp_prepro(seq_len=150,vocab=CN_VOCAB_SIZE,char2idx = char2idx_cn,idx2char=idx2char_cn)

trn_cn_bc = cn_pre.to_bcolz("/data/nlp/%s_cn"%(TASK),trn_cn,cn_pre.split_cn)

py_pre = nlp_prepro(seq_len=200,vocab=PY_VOCAB_SIZE,char2idx = char2idx_py,idx2char=idx2char_py)

trn_py_bc = py_pre.to_bcolz("/data/nlp/%s_py"%(TASK),trn_py,py_pre.split_py)

tk_pre = nlp_prepro(seq_len=150,vocab=TK_VOCAB_SIZE,char2idx = char2idx_tk,idx2char=idx2char_tk)

trn_tk_bc = tk_pre.to_bcolz("/data/nlp/%s_tk"%(TASK),trn_tk,tk_pre.split_tk)
# Out:
# 100%|██████████| 3740/3740 [00:05<00:00, 629.30it/s]
# 100%|██████████| 3740/3740 [00:06<00:00, 605.08it/s]
# 100%|██████████| 3740/3740 [00:05<00:00, 628.80it/s]

# %%
trn_cn_bc
# Out:
# carray((3740, 150), int64)
#   nbytes := 4.28 MB; cbytes := 602.74 KB; ratio: 7.27
#   cparams := cparams(clevel=5, shuffle=1, cname='lz4', quantize=0)
#   chunklen := 13; chunksize: 15600; blocksize: 15600
#   rootdir := '/data/nlp/hotel_cn'
#   mode    := 'a'
# [[1999 1999 1999 ..., 1115   32   32]
#  [1999 1999 1999 ...,  272   26   75]
#  [1999 1999 1999 ...,  879    5  222]
#  ...,
#  [1999 1999 1999 ...,   93    1   15]
#  [1999 1999 1999 ...,   18   43   39]
#  [1999 1999 1999 ...,  101  220   71]]

# %%
print(trn_cn_bc.shape)
print(trn_py_bc.shape)
print(trn_tk_bc.shape)
# Out:
# (3740, 150)
# (3740, 200)
# (3740, 150)

# %%
val_cn_pre = nlp_prepro(seq_len=150,vocab=CN_VOCAB_SIZE,char2idx = char2idx_cn,idx2char=idx2char_cn)

val_cn_bc = val_cn_pre.to_bcolz("/data/nlp/val_%s_cn"%(TASK),val_cn.reset_index()[TASK],val_cn_pre.split_cn)

val_py_pre = nlp_prepro(seq_len=200,vocab=PY_VOCAB_SIZE,char2idx = char2idx_py,idx2char=idx2char_py)

val_py_bc = val_py_pre.to_bcolz("/data/nlp/val_%s_py"%(TASK),val_py.reset_index()[TASK+"_py"],val_py_pre.split_py)

val_tk_pre = nlp_prepro(seq_len=150,vocab=TK_VOCAB_SIZE,char2idx = char2idx_tk,idx2char=idx2char_tk)

val_tk_bc = val_tk_pre.to_bcolz("/data/nlp/val_%s_tk"%(TASK),val_tk.reset_index()["tk_list"],val_tk_pre.split_tk)
# Out:
# 100%|██████████| 936/936 [00:01<00:00, 606.16it/s]
# 100%|██████████| 936/936 [00:01<00:00, 498.76it/s]
# 100%|██████████| 936/936 [00:01<00:00, 582.29it/s]

# %%
train_lbl = list(train_df[TAG_FIELD].apply(lambda x:0 if x=="GOOD" else 1))
valid_lbl = list(valid_df[TAG_FIELD].apply(lambda x:0 if x=="GOOD" else 1))

# %%
trn_y = bcolz.carray(np.eye(2)[train_lbl],rootdir = "/data/nlp/trn_y_%s"%TASK,dtype="int")

val_y = bcolz.carray(np.eye(2)[valid_lbl],rootdir = "/data/nlp/val_y_%s"%TASK,dtype="int")

# %% [markdown]
# ##  LSTM

# %%
from keras.layers import *
from keras.models import *

# %%
def txt_ipt(text_name,seq_len,vocab_size,fac_n):
    # return input layer and flattened embedding layer
    ipt=Input((seq_len,),name="ipt_"+text_name)
    emb=Embedding(vocab_size,fac_n,input_shape=(1,seq_len),name="emb_"+text_name)(ipt)
    # before Flatten(), so 2D dropout
    emb=SpatialDropout1D(rate=0.7)(emb)
    emb=LSTM(40,name="lstm_"+text_name)(emb)
    return ipt,emb

# %%
dr_rate=0.6
# Input & Embedding Layers
ipt,emb=txt_ipt(TASK,150,CHAR_SIZE,FACTOR_NB)
cn_ipt,cn_emb=txt_ipt(TASK+"_cn",150,CN_VOCAB_SIZE,FACTOR_NB)
py_ipt,py_emb=txt_ipt(TASK+"_py",200,PY_VOCAB_SIZE,FACTOR_NB)
#py_ipt,py_emb=txt_ipt("hob_py",50,py_vocab_size,factor_nb)
# Concatenate Embedding
d1=concatenate([emb,cn_emb,py_emb],axis=1)
d2=Dense(1024,activation="relu")(d1)
d2=Dropout(dr_rate)(d2)
d2=Dense(512,activation="relu")(d2)
d2=Dropout(dr_rate)(d2)
output=Dense(LABEL_LEN,activation="softmax",name="Output_Layer")(d2)

# %%
model=Model([ipt,cn_ipt,py_ipt],output)
model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ipt_hotel (InputLayer)          (None, 150)          0
# __________________________________________________________________________________________________
# ipt_hotel_cn (InputLayer)       (None, 150)          0
# __________________________________________________________________________________________________
# ipt_hotel_py (InputLayer)       (None, 200)          0
# __________________________________________________________________________________________________
# emb_hotel (Embedding)           (None, 150, 30)      90000       ipt_hotel[0][0]
# __________________________________________________________________________________________________
# emb_hotel_cn (Embedding)        (None, 150, 30)      60000       ipt_hotel_cn[0][0]
# __________________________________________________________________________________________________
# emb_hotel_py (Embedding)        (None, 200, 30)      1500        ipt_hotel_py[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 150, 30)      0           emb_hotel[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 150, 30)      0           emb_hotel_cn[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 200, 30)      0           emb_hotel_py[0][0]
# __________________________________________________________________________________________________
# lstm_hotel (LSTM)               (None, 40)           11360       spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# lstm_hotel_cn (LSTM)            (None, 40)           11360       spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# lstm_hotel_py (LSTM)            (None, 40)           11360       spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 120)          0           lstm_hotel[0][0]
#                                                                  lstm_hotel_cn[0][0]
#                                                                  lstm_hotel_py[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         123904      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024)         0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          524800      dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# Output_Layer (Dense)            (None, 2)            1026        dropout_4[0][0]
# ==================================================================================================
# Total params: 835,310
# Trainable params: 835,310
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# from keras import callbacks

# SAVE_DIR="/data/logs"
# tb=callbacks.TensorBoard(log_dir=SAVE_DIR+TASK,batch_size=128,write_graph=True)

# %%
BATCH_SIZE = 128
class bcolz_gen:
    def __init__(self,tk_array,cn_array, py_array, y,batch_size=BATCH_SIZE):
        self.tk_array = tk_array
        self.cn_array = cn_array
        self.py_array = py_array
        self.y = y
        self.batch_size = batch_size
        self.idx=0
        self.n=int(len(self.tk_array)/self.batch_size)
        
    def __len__(self):
        return self.n
    
    def __next__(self):
        self.idx_a = self.idx*self.batch_size
        self.idx_b = self.idx_a + self.batch_size
        rt = [self.tk_array[self.idx_a:self.idx_b],self.cn_array[self.idx_a:self.idx_b],self.py_array[self.idx_a:self.idx_b]],self.y[self.idx_a:self.idx_b]
#         self.tk_array.flush()
#         self.cn_array.flush()
#         self.py_array.flush()
        self.y.flush()
        self.idx +=1
        if self.idx == self.n: self.idx=0
        return rt

# %%
trn_gen=bcolz_gen(tk_array=trn_tk_bc,cn_array=trn_cn_bc,py_array=trn_py_bc,y=trn_y)
val_gen=bcolz_gen(tk_array=val_tk_bc,cn_array=val_cn_bc,py_array=val_py_bc,y=val_y)

# %%
model.optimizer.lr=1e-3
model.fit_generator(trn_gen,steps_per_epoch=trn_gen.n,epochs=10,validation_data=val_gen,validation_steps=val_gen.n)
# Out:
# Epoch 1/10
# 29/29 [==============================] - 20s 704ms/step - loss: 0.6901 - acc: 0.5393 - prec_evil: 0.9205 - recall_evil: 0.6188 - val_loss: 0.6803 - val_acc: 0.5993 - val_prec_evil: 0.9754 - val_recall_evil: 0.6239
# Epoch 2/10
# 29/29 [==============================] - 19s 650ms/step - loss: 0.6016 - acc: 0.6695 - prec_evil: 0.8798 - recall_evil: 0.7896 - val_loss: 0.5129 - val_acc: 0.7422 - val_prec_evil: 0.8449 - val_recall_evil: 0.8973
# Epoch 3/10
# 29/29 [==============================] - 19s 646ms/step - loss: 0.4378 - acc: 0.7971 - prec_evil: 0.9052 - recall_evil: 0.8920 - val_loss: 0.4268 - val_acc: 0.8114 - val_prec_evil: 0.8895 - val_recall_evil: 0.9219
# Epoch 4/10
# 29/29 [==============================] - 19s 663ms/step - loss: 0.3738 - acc: 0.8440 - prec_evil: 0.9273 - recall_evil: 0.9168 - val_loss: 0.3638 - val_acc: 0.8504 - val_prec_evil: 0.9163 - val_recall_evil: 0.9342
# Epoch 5/10
# 29/29 [==============================] - 19s 658ms/step - loss: 0.3083 - acc: 0.8774 - prec_evil: 0.9394 - recall_evil: 0.9380 - val_loss: 0.3381 - val_acc: 0.8761 - val_prec_evil: 0.9297 - val_recall_evil: 0.9464
# Epoch 6/10
# 29/29 [==============================] - 20s 676ms/step - loss: 0.2665 - acc: 0.8939 - prec_evil: 0.9464 - recall_evil: 0.9475 - val_loss: 0.3385 - val_acc: 0.8605 - val_prec_evil: 0.9487 - val_recall_evil: 0.9118
# Epoch 7/10
# 29/29 [==============================] - 18s 634ms/step - loss: 0.2367 - acc: 0.9119 - prec_evil: 0.9542 - recall_evil: 0.9577 - val_loss: 0.3973 - val_acc: 0.8571 - val_prec_evil: 0.9598 - val_recall_evil: 0.8973
# Epoch 8/10
# 29/29 [==============================] - 18s 634ms/step - loss: 0.2261 - acc: 0.9089 - prec_evil: 0.9537 - recall_evil: 0.9553 - val_loss: 0.3546 - val_acc: 0.8728 - val_prec_evil: 0.9475 - val_recall_evil: 0.9252
# Epoch 9/10
# 29/29 [==============================] - 17s 602ms/step - loss: 0.1880 - acc: 0.9329 - prec_evil: 0.9628 - recall_evil: 0.9701 - val_loss: 0.3539 - val_acc: 0.8728 - val_prec_evil: 0.9342 - val_recall_evil: 0.9386
# Epoch 10/10
# 29/29 [==============================] - 17s 598ms/step - loss: 0.1736 - acc: 0.9356 - prec_evil: 0.9696 - recall_evil: 0.9661 - val_loss: 0.3776 - val_acc: 0.8661 - val_prec_evil: 0.9163 - val_recall_evil: 0.9498
